# %% [markdown]
# # REST APIs con Python

# %% [markdown]
# Hay una cantidad increíble de datos disponibles en la web. Muchos servicios web, como YouTube y GitHub, hacen que sus datos sean accesibles a aplicaciones de terceros a través de una interfaz de programación de aplicaciones (API). Una de las formas más populares de construir APIs es con el estilo de arquitectura REST. Python proporciona algunas herramientas excelentes no sólo para obtener datos de las APIs REST, sino también para construir tus propias APIs REST en Python.
#
# Utilizando Python y las APIs REST, puedes recuperar, analizar, actualizar y manipular los datos proporcionados por cualquier servicio web que te interese.

# %% [markdown]
# ## Arquitectura REST y servicios Web REST

# %% [markdown]
# REST significa [representational state transfer](https://en.wikipedia.org/wiki/Representational_state_transfer) y es un estilo de arquitectura de software que define un patrón para las comunicaciones entre cliente y servidor a través de una red. REST proporciona un conjunto de restricciones para que la arquitectura del software promueva el rendimiento, la escalabilidad, la simplicidad y la fiabilidad del sistema.

# %% [markdown]
# Un servicio web REST es cualquier servicio web que se adhiere a las restricciones de la arquitectura REST. Estos servicios web exponen sus datos al mundo exterior a través de una API. Las APIs REST proporcionan acceso a los datos del servicio web a través de URLs web públicas.
#
# Por ejemplo, esta es una de las URL de la API REST de GitHub:
#
# ```
# https://api.github.com/users/<nombredeusuario>
# ```
#
# Esta URL te permite acceder a información sobre un usuario específico de GitHub. El acceso a los datos de una API REST se realiza enviando una solicitud HTTP a una URL específica y procesando la respuesta.

# %% [markdown]
# ## Métodos HTTP

# %% [markdown]
# Las APIs REST escuchan métodos HTTP como GET, POST y DELETE para saber qué operaciones realizar en los recursos del servicio web. Un recurso es cualquier dato disponible en el servicio web al que se puede acceder y manipular con peticiones HTTP a la API REST. El método HTTP indica a la API qué acción debe realizar sobre el recurso.
#
# Aunque hay muchos métodos HTTP, los cinco métodos que se enumeran a continuación son los más utilizados con las APIs REST:

# %% [markdown]
# <table class="table table-hover">
# <thead>
# <tr>
# <th>HTTP method</th>
# <th>Description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><code>GET</code></td>
# <td>Retrieve an existing resource.</td>
# </tr>
# <tr>
# <td><code>POST</code></td>
# <td>Create a new resource.</td>
# </tr>
# <tr>
# <td><code>PUT</code></td>
# <td>Update an existing resource.</td>
# </tr>
# <tr>
# <td><code>PATCH</code></td>
# <td>Partially update an existing resource.</td>
# </tr>
# <tr>
# <td><code>DELETE</code></td>
# <td>Delete a resource.</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Códigos de status

# %% [markdown]
# Una vez que una API REST recibe y procesa una solicitud HTTP, devolverá una respuesta HTTP. En esta respuesta se incluye un código de estado HTTP. Este código proporciona información sobre los resultados de la solicitud. Una aplicación que envíe solicitudes a la API puede comprobar el código de estado y realizar acciones basadas en el resultado. Estas acciones pueden incluir la gestión de errores o la visualización de un mensaje de éxito a un usuario.
#
# A continuación se muestra una lista de los códigos de estado más comunes devueltos por las APIs de REST:
#
# <div class="table-responsive">
# <table class="table table-hover">
# <thead>
# <tr>
# <th>Code</th>
# <th>Meaning</th>
# <th>Description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><code>200</code></td>
# <td>OK</td>
# <td>The requested action was successful.</td>
# </tr>
# <tr>
# <td><code>201</code></td>
# <td>Created</td>
# <td>A new resource was created.</td>
# </tr>
# <tr>
# <td><code>202</code></td>
# <td>Accepted</td>
# <td>The request was received, but no modification has been made yet.</td>
# </tr>
# <tr>
# <td><code>204</code></td>
# <td>No Content</td>
# <td>The request was successful, but the response has no content.</td>
# </tr>
# <tr>
# <td><code>400</code></td>
# <td>Bad Request</td>
# <td>The request was malformed.</td>
# </tr>
# <tr>
# <td><code>401</code></td>
# <td>Unauthorized</td>
# <td>The client is not authorized to perform the requested action.</td>
# </tr>
# <tr>
# <td><code>404</code></td>
# <td>Not Found</td>
# <td>The requested resource was not found.</td>
# </tr>
# <tr>
# <td><code>415</code></td>
# <td>Unsupported Media Type</td>
# <td>The request data format is not supported by the server.</td>
# </tr>
# <tr>
# <td><code>422</code></td>
# <td>Unprocessable Entity</td>
# <td>The request data was properly formatted but contained invalid or missing data.</td>
# </tr>
# <tr>
# <td><code>500</code></td>
# <td>Internal Server Error</td>
# <td>The server threw an error when processing the request.</td>
# </tr>
# </tbody>
# </table>
# </div>

# %% [markdown]
# ## API Endpoints

# %% [markdown]
# Una API REST expone un conjunto de URLs públicas que las aplicaciones cliente utilizan para acceder a los recursos de un servicio web. Estas URL, en el contexto de una API, se denominan `endpoints`.
#
# Para ayudar a aclarar esto, eche un vistazo a la siguiente tabla. En esta tabla, verá los puntos finales de la API para un hipotético sistema CRM. Estos endpoints son para un recurso de cliente que representa clientes potenciales en el sistema:
#
# <div class="table-responsive">
# <table class="table table-hover">
# <thead>
# <tr>
# <th>HTTP method</th>
# <th>API endpoint</th>
# <th>Description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><code>GET</code></td>
# <td><code>/customers</code></td>
# <td>Get a list of customers.</td>
# </tr>
# <tr>
# <td><code>GET</code></td>
# <td><code>/customers/&lt;customer_id&gt;</code></td>
# <td>Get a single customer.</td>
# </tr>
# <tr>
# <td><code>POST</code></td>
# <td><code>/customers</code></td>
# <td>Create a new customer.</td>
# </tr>
# <tr>
# <td><code>PUT</code></td>
# <td><code>/customers/&lt;customer_id&gt;</code></td>
# <td>Update a customer.</td>
# </tr>
# <tr>
# <td><code>PATCH</code></td>
# <td><code>/customers/&lt;customer_id&gt;</code></td>
# <td>Partially update a customer.</td>
# </tr>
# <tr>
# <td><code>DELETE</code></td>
# <td><code>/customers/&lt;customer_id&gt;</code></td>
# <td>Delete a customer.</td>
# </tr>
# </tbody>
# </table>
# </div>

# %% [markdown]
# **Nota**: Se omite por brevedad, pero la URL completa sería del tipo `https://api.example.com/customers`

# %% [markdown]
# Observará que algunos endpoints tienen `<customer_id>` al final. Esta notación significa que debe añadir un customer_id numérico a la URL para indicar a la API REST con qué cliente desea trabajar.
#
# Los endpoints enumerados anteriormente representan sólo un recurso del sistema. Las API REST listas para la producción suelen tener decenas o incluso cientos de endpoints diferentes para gestionar los recursos del servicio web.

# %% [markdown]
# ## Consumir APIs con Python

# %% [markdown]
# Para escribir código que interactúe con las APIs REST, la mayoría de los desarrolladores de Python recurren ala librería `requests` para enviar solicitudes HTTP. Esta librería abstrae las complejidades de hacer peticiones HTTP.
#
# Para empezar a usar `requests`, necesitas instalarla primero. Puedes usar pip:

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\mgilj\appdata\local\programs\python\python37\lib\site-packages (2.28.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mgilj\appdata\local\programs\python\python37\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mgilj\appdata\local\programs\python\python37\lib\site-packages (from requests) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mgilj\appdata\local\programs\python\python37\lib\site-packages (from requests) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mgilj\appdata\local\programs\python\python37\lib\site-packages (from requests) (3.1.0)

# %% [markdown]
# ### GET

# %% [markdown]
# GET es uno de los métodos HTTP más comunes que utilizará cuando trabaje con APIs REST. Este método le permite recuperar recursos de una determinada API. GET es una operación de **sólo lectura**, por lo que no debe utilizarla para modificar un recurso existente.
#
# Para probar GET y los demás métodos de esta sección, utilizarás un servicio llamado JSONPlaceholder. Este servicio gratuito proporciona puntos finales de API falsos que devuelven respuestas que las solicitudes pueden procesar.
#
# Para probarlo, inicia el REPL de Python y ejecuta los siguientes comandos para enviar una solicitud GET a un punto final de JSONPlaceholder:

# %%
import requests
api_url = "https://jsonplaceholder.typicode.com/todos/1"
response = requests.get(api_url)
response.json()
# Out:
# {'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}

# %% [markdown]
# Este código llama a `requests.get()` para enviar una petición GET a `/todos/1`, que responde con el elemento todo con el ID 1. A continuación, puede llamar a `.json()` en el objeto de respuesta para ver los datos devueltos por la API.
#
# Los datos de la respuesta están formateados como JSON, un almacén de clave-valor similar a un diccionario de Python. Es un formato de datos muy popular y el formato de intercambio de facto para la mayoría de las APIs REST.
#
# Además de ver los datos JSON de la API, también puede ver otras cosas sobre la respuesta:

# %%
print(response.status_code)
print(response.headers["Content-Type"])
print(response.headers)
# Out:
# 200
# application/json; charset=utf-8
# {'Date': 'Wed, 22 Mar 2023 09:58:31 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'X-Powered-By': 'Express', 'X-Ratelimit-Limit': '1000', 'X-Ratelimit-Remaining': '999', 'X-Ratelimit-Reset': '1677075913', 'Vary': 'Origin, Accept-Encoding', 'Access-Control-Allow-Credentials': 'true', 'Cache-Control': 'max-age=43200', 'Pragma': 'no-cache', 'Expires': '-1', 'X-Content-Type-Options': 'nosniff', 'Etag': 'W/"53-hfEnumeNh6YirfjyjaujcOPPT+s"', 'Via': '1.1 vegur', 'CF-Cache-Status': 'HIT', 'Age': '5010', 'Server-Timing': 'cf-q-config;dur=7.0000005507609e-06', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report\\/v3?s=KAIsLgPbJ8i8BRcKXvWyBhUR23UtzCWd%2FVoEnS0SUouNGepICfKbGE1EMT4nkixBVMecl2Y%2BJcxCYM26HCK%2BIdxKwQR5NKWEu%2F%2BJX0CgV9UWI4kvjxC%2FIP0WMTdABLat%2BL5OTJMaHS3N3V2eliFu"}],"group":"cf-nel","max_age":604800}', 'NEL': '{"success_fraction":0,"report_to":"cf-nel","max_age":604800}', 'Server': 'cloudflare', 'CF-RAY': '7abd939fdb4b6653-MAD', 'Content-Encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400, h3-29=":443"; ma=86400'}

# %% [markdown]
# Aquí se accede a `response.status_code` para ver el código de estado HTTP. También puedes ver las cabeceras HTTP de la respuesta con `response.headers`. Este diccionario contiene metadatos sobre la respuesta, como el Content-Type de la respuesta.

# %% [markdown]
# ### POST

# %% [markdown]
# Aquí se llama a `requests.post()` para crear una nueva tarea en el sistema.
#
# 1. Se crea un diccionario que contiene los datos de la tarea
# 2. Pasa este diccionario al argumento de la palabra clave json de `requests.post()`
# 3. Al hacer esto, requests.post() automáticamente establece el encabezado HTTP Content-Type de la solicitud a application/json. También serializa todo en una cadena JSON, que añade al cuerpo de la petición.

# %%
api_url = "https://jsonplaceholder.typicode.com/todos"
todo = {"userId": 1, "title": "Buy milk", "completed": False}
response = requests.post(api_url, json=todo)
print(response.json())
print(response.status_code)
# Out:
# {'userId': 1, 'title': 'Buy milk', 'completed': False, 'id': 201}
# 201

# %% [markdown]
# Si no utiliza el argumento `json` en la función para suministrar los datos JSON, deberá establecer el `Content-Type` correspondiente y serializar el JSON manualmente. Aquí hay una versión equivalente al código anterior:

# %%
import json
api_url = "https://jsonplaceholder.typicode.com/todos"
todo = {"userId": 1, "title": "Buy milk", "completed": False}
headers =  {"Content-Type":"application/json"}
response = requests.post(api_url, data=json.dumps(todo), headers=headers)

print(response.json())
print(response.status_code)
# Out:
# {'userId': 1, 'title': 'Buy milk', 'completed': False, 'id': 201}
# 201

# %% [markdown]
# ### PUT

# %%
api_url = "https://jsonplaceholder.typicode.com/todos/10"
response = requests.get(api_url)
print(response.json())
# Out:
# {'userId': 1, 'id': 10, 'title': 'illo est ratione doloremque quia maiores aut', 'completed': True}

# %%
todo = {"userId": 1, "title": "Wash car", "completed": True}
response = requests.put(api_url, json=todo)
print(response.json())
print(response.status_code)
# Out:
# {'userId': 1, 'title': 'Wash car', 'completed': True, 'id': 10}
# 200

# %% [markdown]
# ### PATCH

# %%
api_url = "https://jsonplaceholder.typicode.com/todos/10"
todo = {"title": "Mow lawn"}
response = requests.patch(api_url, json=todo)
print(response.json())
print(response.status_code)
# Out:
# {'userId': 1, 'id': 10, 'title': 'Mow lawn', 'completed': True}
# 200

# %% [markdown]
# ### DELETE

# %%
api_url = "https://jsonplaceholder.typicode.com/todos/10"
response = requests.delete(api_url)
response.json()
# Out:
# {}

# %% [markdown]
# ## Ejemplo: Datos Sevici

# %% [markdown]
# Hoy en día, una gran cantidad de sitios web facilitan acceso a sus datos a través de API RESTs. Un ejemplo es la siguiente web con información geográfica sobre distintos aspectos de nuestra ciudad.

# %%
# En la web encontramos la especificación de la API que nos interesa
url = 'https://services1.arcgis.com/hcmP7kr0Cx3AcTJk/arcgis/rest/services/Estaciones_Sevici/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json'
# Obtenemos los datos correspondientes con request y lo guardamos en una variable
data = requests.get(url)
# Escribimos el json para poder pasarlo por un Beautifier (https://codebeautify.org/jsonviewer) 
# que nos permite visualizarlo de manera sencilla
type(data)
print(data.status_code)
print(data)
print(data.headers)
print(type(data.content))
print(type(data.json()))
# Out:
# 200
# <Response [200]>
# {'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '14377', 'Connection': 'keep-alive', 'Cache-Control': 'public, max-age=30, s-maxage=30', 'Content-Encoding': 'gzip', 'Last-Modified': 'Wed, 22 Feb 2017 12:29:58 GMT', 'X-ArcGIS-Trace-Id': '254c5aaee2282e08bec9997446bae554', 'x-esri-query-request-units': '2', 'x-esri-tiles-basic-query-mode': 'true', 'x-esri-tiles-basic-query-type': 'Basic', 'x-esri-org-request-units-per-min': 'usage=14;max=6000', 'x-esri-query-geometry-field-name': 'Shape', 'X-ArcGIS-Correlation-Id': '00-254c5aaee2282e08bec9997446bae554-df48c78a0e684f3e-00', 'X-ArcGIS-Instance': 'i7tdixsfq000008', 'Strict-Transport-Security': 'max-age=63072000', 'Access-Control-Allow-Origin': '*', 'Date': 'Wed, 22 Mar 2023 09:58:34 GMT', 'ETag': 'sd1215_-1958504146', 'X-Cache': 'RefreshHit from cloudfront', 'Via': '1.1 b5e354980da78aef02917b4456c540c0.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'MAD56-P2', 'X-Amz-Cf-Id': 'w_6Abm-vzwb1h3wmhuMH1aXqSbjyVtXVk-IziYo5qpQXnd9lv650xQ=='}
# <class 'bytes'>
# <class 'dict'>

# %% [markdown]
# El formato de los datos no es muy amigable pero con un poco de exploración encontramos la información que nos interesa

# %%
# Guardamos la respuesta en un diccionario
# Con el método .json() de la request directamente 
# leemos el json como diccionario
# Sacamos los datos usando bucles o listas por comprension
data_json = data.json()
data_json.keys()
data_json['features']
rows = [x['attributes'] for x in data_json['features']]
#Otra forma de hacerlo:
# rows = []
# for dic in data_json:
#     rows.append(dic['attributes'])
    
# rows
import pandas as pd
df_sevici = pd.DataFrame(rows)
df_sevici
# Out:
#      FID  id_estacio                   Direccion  \
# 0      1           1           Glorieta Olimpica
# 1      2           2                  Gran Plaza
# 2      3           3       Puerta de la Barqueta
# 3      4           4     Calle Leonardo Da Vinci
# 4      5         131            Calle Tabladilla
# ..   ...         ...                         ...
# 255  256         256        Plaza Miguel Montoro
# 256  257         257  Plaza Torres de Albarracín
# 257  258         258       Calle Estaca de Vares
# 258  259         259            Calle 8 de Marzo
# 259  260         260     Avenida de la Revoltosa
#
#                             Aproximaci      Lat_Y     Lon_X   CreationDate  \
# 0    Concejal Alberto Jiménez-Becerril  37.412983 -5.988933  1412457692379
# 1             Calle Marquez de Pickman  37.381664 -5.965183  1412457692379
# 2                Puente de la Barqueta  37.405640 -5.998514  1412457692379
# 3             Calle Thomas Alba Edison  37.410126 -6.005659  1412457692379
# 4              Calle Cardenal Ilundaín  37.364746 -5.981396  1412457692379
# ..                                 ...        ...       ...            ...
# 255                   Calle Pero Mingo  37.385987 -5.910274  1412457692379
# 256             Plaza Corazón de María  37.384210 -5.909692  1412457692379
# 257                        Calle Creus  37.383797 -5.914633  1412457692379
# 258             Calle Aguila Perdicera  37.367181 -5.954483  1412457692379
# 259             Centro Deportivo Amate  37.378641 -5.948474  1412457692379
#
#           Creator       EditDate        Editor
# 0    Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 1    Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 2    Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 3    Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 4    Ayto.Sevilla  1412457692379  Ayto.Sevilla
# ..            ...            ...           ...
# 255  Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 256  Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 257  Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 258  Ayto.Sevilla  1412457692379  Ayto.Sevilla
# 259  Ayto.Sevilla  1412457692379  Ayto.Sevilla
#
# [260 rows x 10 columns]

# %% [markdown]
# Ahora podemos escribir los datos en un dataframe de pandas que nos permita usar todo lo que hemos aprendido hasta ahora

# %%
api_key="b26b8ad419acf7165646f3866af2ac542d1e5a82"

# url=f"https://api.jcdecaux.com/vls/v1/stations?contract={contract_name}&apiKey={api_key}"

url=f"https://api.jcdecaux.com/vls/v1/contracts?apiKey={api_key}"
req_contracts=requests.get(url)
ls_contracts=req_contracts.json()

len(ls_contracts) #Por lo que tiene 27 contratos con ciudades
# Out:
# 27

# %%
contract_name="seville"
api_key="b26b8ad419acf7165646f3866af2ac542d1e5a82"

url2=f"https://api.jcdecaux.com/vls/v1/stations?contract={contract_name}&apiKey={api_key}"
req_stations=requests.get(url2)
ls_stations=req_stations.json()
df_stations=pd.DataFrame(ls_stations)
df_stations
# Out:
#      number contract_name                        name  \
# 0       194       seville  194_CALLE PARQUE DE DOÑANA
# 1       126       seville  126_AVENIDA REINA MERCEDES
# 2        73       seville       073_PLAZA SAN AGUSTIN
# 3       100       seville   100_PASEO CATALINA RIBERA
# 4        96       seville             096_CALLE BETIS
# ..      ...           ...                         ...
# 252     146       seville  146_AVENIDA REINA MERCEDES
# 253     135       seville   135_CALLE VIRGEN DE LUJÁN
# 254     215       seville            215_CALLE ZORZAL
# 255     162       seville           162_AVENIDA SOLEA
# 256      10       seville         010_CALLE JOSE DIAZ
#
#                                                address  \
# 0    CALLE PARQUE DE DOÑANA - Aprox. Calle Corral d...
# 1    AVENIDA REINA MERCEDES - Aprox. Facultad de In...
# 2             PLAZA SAN AGUSTIN - Aprox. C/ Concepción
# 3       PASEO CATALINA RIBERA - Aprox. C/ San Fernando
# 4                 CALLE BETIS - Aprox. C/ Juan de Lugo
# ..                                                 ...
# 252  AVENIDA REINA MERCEDES - Aprox. C/ Profesor Ga...
# 253  CALLE VIRGEN DE LUJÁN - Aprox. Glorieta las Ci...
# 254         CALLE ZORZAL - Aprox. Avenida de Andalucia
# 255           AVENIDA SOLEA - Aprox. C/ Media Granaína
# 256  CALLE JOSE DIAZ - Aprox. Avda Concejal Alberto...
#
#                                               position  banking  bonus  \
# 0                 {'lat': 37.418586, 'lng': -5.973249}    False  False
# 1                 {'lat': 37.358414, 'lng': -5.986423}    False  False
# 2                  {'lat': 37.38962, 'lng': -5.984551}    False  False
# 3                 {'lat': 37.381542, 'lng': -5.989222}    False  False
# 4                 {'lat': 37.383674, 'lng': -6.000026}    False  False
# ..                                                 ...      ...    ...
# 252               {'lat': 37.360007, 'lng': -5.986374}    False  False
# 253               {'lat': 37.374664, 'lng': -5.994932}    False  False
# 254  {'lat': 37.3866414802585, 'lng': -5.9539810741...    False  False
# 255                {'lat': 37.39155, 'lng': -5.968485}    False  False
# 256               {'lat': 37.409109, 'lng': -5.990943}    False  False
#
#      bike_stands  available_bike_stands  available_bikes status    last_update
# 0             20                     12                8   OPEN  1679478749000
# 1             25                      9               16   OPEN  1679478496000
# 2             15                     15                0   OPEN  1679478826000
# 3             20                      0               19   OPEN  1679478661000
# 4             19                      3               16   OPEN  1679478857000
# ..           ...                    ...              ...    ...            ...
# 252           20                      0               20   OPEN  1679479052000
# 253           17                      3               14   OPEN  1679478966000
# 254           15                      9                6   OPEN  1679479014000
# 255           18                     13                4   OPEN  1679479057000
# 256           20                     14                6   OPEN  1679478706000
#
# [257 rows x 12 columns]

# %%
#Definimos una función 
def get_station(api_key, contract_name, station_number=None):
    if station_number is None:
        url=f"https://api.jcdecaux.com/vls/v1/stations?contract={contract_name}&apiKey={api_key}"
    else:
        url=f"https://api.jcdecaux.com/vls/v1/stations/{station_number}?contract={contract_name}&apiKey={api_key}"
    
    data=requests.get(url)
    ls_data=data.json()
    ls_data=ls_data if type(ls_data)==list else[ls_data]
    df=pd.DataFrame(ls_data)
    df["lat"]=df["position"].apply(lambda x: x["lat"])
    df["lng"]=df["position"].apply(lambda x: x["lng"])
    df.drop(columns="position", inplace=True)
    return df

# %%
dff=get_station(api_key,contract_name,100)
dff
# Out:
#    number contract_name                       name  \
# 0     100       seville  100_PASEO CATALINA RIBERA
#
#                                           address  banking  bonus  \
# 0  PASEO CATALINA RIBERA - Aprox. C/ San Fernando    False  False
#
#    bike_stands  available_bike_stands  available_bikes status    last_update  \
# 0           20                      0               19   OPEN  1679479265000
#
#          lat       lng
# 0  37.381542 -5.989222

# %% [markdown]
# Parece que el lugar en el que es más necesario especificar la aproximación es en la Calle Asunción

# %%
df_sevici.groupby('Aproximaci')['FID'].count().sort_values(ascending=False)
# Contamos el numero de Aproximaci y ordenamos para ver donde hay mas sevicis
# Out:
# Aproximaci
# Calle Asunción                    3
# Calle Profesor García González    2
# Calle Pino Montano                2
# Calle Albert Einstein             2
# Calle Fray Isidoro de Sevilla     2
#                                  ..
# Calle Flor de Salvia              1
# Calle Fuenteovejuna               1
# Calle Gonzalo de Bilbao           1
# Calle González Cuadrado           1
# Virgen de la Victoria             1
# Name: FID, Length: 242, dtype: int64

# %%
point1=df_sevici.loc[df_sevici["Aproximaci"]=="Centro Deportivo Amate", ["Lat_Y","Lon_X"]].values
point2=df_sevici.loc[df_sevici["Aproximaci"]=="Centro Deportivo Entreflores", ["Lat_Y","Lon_X"]].values
from geopy.distance import geodesic

dist=geodesic(point1,point2)

dist
# Out:
# Distance(3.355825195044264)

# %% [markdown]
# Podemos sacar las posiciones de las estaciones que más nos interesen

# %%
# Sacamos una posicion

# %% [markdown]
# Con el módulo `geopy` se puede encontrar la distancia geodésica (camino más corto sobre la superficie terrestre) entre dos estaciones de sevici

# %% [markdown]
# ## Ejemplo 2: OpenStreet Maps

# %%
import requests
import json
import pandas as pd
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
node["amenity"="restaurant"]
  (37.3953289, -5.9914891, 37.3998008, -5.9916412); 
out;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
print(response)
data = response.json()
data
# Out:
# <Response [200]>
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.59.2 0994154d',
#  'osm3s': {'timestamp_osm_base': '2023-03-22T10:24:22Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 308971231,
#    'lat': 37.3968705,
#    'lon': -5.9967756,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.10f',
#     'name': 'Bar San Lorenzo'}},
#   {'type': 'node',
#    'id': 308971742,
#    'lat': 37.3969679,
#    'lon': -5.9963185,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.10f',
#     'name': 'Cafe Bar El Sardinero'}},
#   {'type': 'node',
#    'id': 308972662,
#    'lat': 37.3967979,
#    'lon': -5.9945413,
#    'tags': {'amenity': 'restaurant', 'name': 'Almeda 5'}},
#   {'type': 'node',
#    'id': 368963895,
#    'lat': 37.399173,
#    'lon': 126.918,
#    'tags': {'amenity': 'restaurant',
#     'name': '율도횟집',
#     'name:en': 'Yuldo Fish Restaurant',
#     'name:ko': '율도횟집',
#     'name:ko-Latn': 'Yuldohoetjip',
#     'source': 'http://kr.open.gugi.yahoo.com'}},
#   {'type': 'node',
#    'id': 457319060,
#    'lat': 37.3989116,
#    'lon': 126.9234754,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Lotteria',
#     'name:ko': 'Lotteria'}},
#   {'type': 'node',
#    'id': 491257310,
#    'lat': 37.3974972,
#    'lon': -5.9930588,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'spanish',
#     'name': 'La Sopa Boba'}},
#   {'type': 'node',
#    'id': 748469180,
#    'lat': 37.3966631,
#    'lon': -5.9939661,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'tapas', 'name': 'Cruo'}},
#   {'type': 'node',
#    'id': 1005405698,
#    'lat': 37.3992764,
#    'lon': -2.9925147,
#    'tags': {'amenity': 'restaurant', 'name': 'Hermanos Vergara'}},
#   {'type': 'node',
#    'id': 1290539367,
#    'lat': 37.3964006,
#    'lon': -5.9945136,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'Il Forno'}},
#   {'type': 'node',
#    'id': 1290554303,
#    'lat': 37.3967324,
#    'lon': -5.994288,
#    'tags': {'amenity': 'restaurant', 'name': 'Karpanta'}},
#   {'type': 'node',
#    'id': 1383397365,
#    'lat': 37.3983537,
#    'lon': -5.9943094,
#    'tags': {'addr:housenumber': '29',
#     'addr:postcode': '41002',
#     'addr:street': 'Alameda de Hércules',
#     'amenity': 'restaurant',
#     'brand': 'Pomodoro',
#     'brand:website': 'https://pomodoro.es',
#     'brand:wikidata': 'Q115475288',
#     'cuisine': 'italian;pasta;pizza',
#     'name': 'Pomodoro',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1440032358,
#    'lat': 37.3972883,
#    'lon': -122.1078244,
#    'tags': {'addr:city': 'Los Altos',
#     'addr:housenumber': '4926',
#     'addr:postcode': '94022',
#     'addr:state': 'CA',
#     'addr:street': 'West El Camino Real',
#     'addr:unit': '9',
#     'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'diet:vegetarian': 'yes',
#     'name': 'Amber India'}},
#   {'type': 'node',
#    'id': 1519597638,
#    'lat': 37.39842,
#    'lon': -5.9879244,
#    'tags': {'amenity': 'restaurant', 'name': 'ConTenedor'}},
#   {'type': 'node',
#    'id': 1596387190,
#    'lat': 37.3976477,
#    'lon': -1.5998027,
#    'tags': {'addr:housenumber': '1',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'Monna Lisa',
#     'opening_hours': 'Tu-Su',
#     'phone': '+34 968449464'}},
#   {'type': 'node',
#    'id': 1668049639,
#    'lat': 37.3981683,
#    'lon': -121.924445,
#    'tags': {'amenity': 'restaurant'}},
#   {'type': 'node',
#    'id': 1847619969,
#    'lat': 37.3974371,
#    'lon': -121.9969379,
#    'tags': {'addr:housenumber': '1135',
#     'addr:street': 'Lawrence Expressway',
#     'amenity': 'restaurant',
#     'check_date': '2023-03-15',
#     'cuisine': 'chinese',
#     'name': 'Hong Kong Saigon Seafood Harbor',
#     'opening_hours': 'Mo-Fr 11:00-14:30, 17:00-21:30; Sa, Su 10:00-15:00, 17:00-21:30'}},
#   {'type': 'node',
#    'id': 1905772847,
#    'lat': 37.3966739,
#    'lon': -5.9904943,
#    'tags': {'amenity': 'restaurant',
#     'capacity': '50',
#     'cuisine': 'pizza',
#     'name': 'Pizzería El Gato Azul',
#     'smoking': 'outside'}},
#   {'type': 'node',
#    'id': 2050156002,
#    'lat': 37.3966595,
#    'lon': -4.7662639,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'spanish',
#     'name': 'Hops Tapas'}},
#   {'type': 'node',
#    'id': 2064591266,
#    'lat': 37.3953792,
#    'lon': -5.9948364,
#    'tags': {'amenity': 'restaurant', 'name': 'El Gallinero de Sandra'}},
#   {'type': 'node',
#    'id': 2066052945,
#    'lat': 37.3975885,
#    'lon': -5.9958717,
#    'tags': {'amenity': 'restaurant', 'name': 'Casa Ricardo'}},
#   {'type': 'node',
#    'id': 2372222363,
#    'lat': 37.396208,
#    'lon': -5.974479,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '13',
#     'addr:postcode': '41008',
#     'addr:street': 'Calle Samaniego',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'Berenice Bristot',
#     'opening_hours': 'We-Th 17:00-23:30; Fr 17:00-24:00; Sa 16:00-24:00; Su 13:30-24:00',
#     'outdoor_seating': 'yes',
#     'smoking': 'outside',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 2417048579,
#    'lat': 37.3992949,
#    'lon': -5.9923078,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '21',
#     'addr:postcode': '41003',
#     'addr:street': 'Calle Peris Mencheta',
#     'amenity': 'restaurant',
#     'name': 'Gibi Tapas',
#     'phone': '+34 954 90 81 88'}},
#   {'type': 'node',
#    'id': 2477050862,
#    'lat': 37.3972078,
#    'lon': -5.9931448,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'regional',
#     'name': 'Dabuten Tapas'}},
#   {'type': 'node',
#    'id': 2526791436,
#    'lat': 37.3995961,
#    'lon': -5.9927957,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '24',
#     'addr:postcode': '41002',
#     'addr:street': 'Calle Mata',
#     'amenity': 'restaurant',
#     'capacity': '50',
#     'cuisine': 'international',
#     'name': 'La Mata 24',
#     'smoking': 'outside'}},
#   {'type': 'node',
#    'id': 2604149614,
#    'lat': 37.3969354,
#    'lon': -121.9969188,
#    'tags': {'addr:housenumber': '1127',
#     'addr:street': 'Lawrence Expressway',
#     'amenity': 'restaurant',
#     'check_date': '2023-03-15',
#     'name': "Giovanni's Pizzeria"}},
#   {'type': 'node',
#    'id': 2604149616,
#    'lat': 37.3973375,
#    'lon': -121.9969354,
#    'tags': {'addr:housenumber': '1129',
#     'addr:street': 'Lawrence Expressway',
#     'amenity': 'restaurant',
#     'check_date': '2023-03-15',
#     'cuisine': 'japanese',
#     'name': 'Homi Japanese Ramen'}},
#   {'type': 'node',
#    'id': 2604149620,
#    'lat': 37.397054,
#    'lon': -121.9969271,
#    'tags': {'addr:housenumber': '1129',
#     'addr:street': 'Lawrence Expressway',
#     'amenity': 'restaurant',
#     'check_date': '2023-03-15',
#     'cuisine': 'chinese',
#     'name': 'Ming Tasty'}},
#   {'type': 'node',
#    'id': 2604149622,
#    'lat': 37.3976314,
#    'lon': -121.996937,
#    'tags': {'addr:housenumber': '1149',
#     'addr:street': 'Lawrence Expressway',
#     'amenity': 'restaurant',
#     'check_date': '2023-03-15',
#     'cuisine': 'chinese',
#     'name': 'Hunan Mifen Chinese Rice Noodles'}},
#   {'type': 'node',
#    'id': 2619982654,
#    'lat': 37.3997633,
#    'lon': -122.1139783,
#    'tags': {'addr:city': 'Los Altos',
#     'addr:housenumber': '971',
#     'addr:postcode': '94022',
#     'addr:street': 'North San Antonio Road',
#     'amenity': 'restaurant',
#     'cuisine': 'mexican',
#     'name': "Estrellita's Mexican Restaurant"}},
#   {'type': 'node',
#    'id': 2686843535,
#    'lat': 37.3980931,
#    'lon': 24.8758136,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Λιμανάκι',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2686844202,
#    'lat': 37.3983317,
#    'lon': 24.8783188,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'greek',
#     'name': 'ORA Baresto',
#     'outdoor_seating': 'yes',
#     'website': 'https://www.facebook.com/ORAsyros/'}},
#   {'type': 'node',
#    'id': 2686844629,
#    'lat': 37.3978661,
#    'lon': 24.8808894,
#    'tags': {'amenity': 'restaurant', 'name': 'Ολυμπία'}},
#   {'type': 'node',
#    'id': 2688626642,
#    'lat': 37.3982045,
#    'lon': 24.879782,
#    'tags': {'amenity': 'restaurant', 'name': 'Το Κύμα'}},
#   {'type': 'node',
#    'id': 3011394583,
#    'lat': 37.3956291,
#    'lon': 126.9633603,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'chinese',
#     'source': 'Mapillary'}},
#   {'type': 'node',
#    'id': 3126118751,
#    'lat': 37.395875,
#    'lon': -5.9956034,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '31',
#     'addr:postcode': '41002',
#     'addr:street': 'Calle Jesús del Gran Poder',
#     'amenity': 'restaurant',
#     'cuisine': 'alta_cocina',
#     'email': 'azoteasevilla@gmail.com',
#     'name': 'La Azotea',
#     'phone': '+34 955116748',
#     'website': 'http://www.laazoteasevilla.es'}},
#   {'type': 'node',
#    'id': 3133040790,
#    'lat': 37.3966105,
#    'lon': -5.993837,
#    'tags': {'addr:postcode': '41002',
#     'addr:street': 'Calle Amor de Dios',
#     'amenity': 'restaurant',
#     'cuisine': 'Pizza_al_taglio',
#     'name': 'Buoni'}},
#   {'type': 'node',
#    'id': 3185244515,
#    'lat': 37.3964735,
#    'lon': 126.6514531,
#    'tags': {'amenity': 'restaurant', 'name': '본가신촌설렁탕'}},
#   {'type': 'node',
#    'id': 3210808445,
#    'lat': 37.3993087,
#    'lon': 126.6367965,
#    'tags': {'amenity': 'restaurant', 'name': '애슐리', 'name:en': 'Ashley'}},
#   {'type': 'node',
#    'id': 3216083142,
#    'lat': 37.3953787,
#    'lon': -5.9908161,
#    'tags': {'amenity': 'restaurant',
#     'capacity': '50',
#     'cuisine': 'regional',
#     'name': 'La Plazoleta',
#     'smoking': 'outside',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 3224711050,
#    'lat': 37.3983129,
#    'lon': 140.363285,
#    'tags': {'amenity': 'restaurant',
#     'brand': 'ラーメン',
#     'name': 'ラーメンくまごろう',
#     'name:ja': 'くまごろう',
#     'opening_hours': '11:00-15:00,18:00-04:00',
#     'phone': '024-923-9276',
#     'website': 'https://tabelog.com/fukushima/A0702/A070201/7006222/'}},
#   {'type': 'node',
#    'id': 3224711164,
#    'lat': 37.3989006,
#    'lon': 140.3634082,
#    'tags': {'amenity': 'restaurant',
#     'brand': '沖縄ダイニング',
#     'name': '沖縄ダイニング\u3000「な美ら」',
#     'name:ja': 'な美ら',
#     'opening_hours': 'Mo-Sa 11:30-14:00,17:30-23:30;Su 11:30-14:45;PH 11:30-14:45',
#     'phone': '024-927-8417',
#     'website': 'http://www.emikaji.com/'}},
#   {'type': 'node',
#    'id': 3224711200,
#    'lat': 37.398302,
#    'lon': 140.3633206,
#    'tags': {'amenity': 'restaurant',
#     'name': 'ミオ・パスタ',
#     'name:ja': 'ミオ・パスタ',
#     'opening_hours': '11:00-15:00,17:30-21:00',
#     'phone': '024-935-2617',
#     'website': 'https://tabelog.com/fukushima/A0702/A070201/7000960/'}},
#   {'type': 'node',
#    'id': 3224711202,
#    'lat': 37.3981899,
#    'lon': 140.3654654,
#    'tags': {'amenity': 'restaurant', 'name': 'ラーメン店', 'name:ja': 'ラーメン店'}},
#   {'type': 'node',
#    'id': 3224711208,
#    'lat': 37.3992664,
#    'lon': 140.3690966,
#    'tags': {'amenity': 'restaurant',
#     'name': '京香',
#     'name:ja': '京香',
#     'phone': '+81 24 932 0220',
#     'website': 'http://www.kyo-ka.jp/'}},
#   {'type': 'node',
#    'id': 3224711256,
#    'lat': 37.3998005,
#    'lon': 140.3621362,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'Best Table',
#     'name:ja': '福ケッチァーノ'}},
#   {'type': 'node',
#    'id': 3233631504,
#    'lat': 37.3978286,
#    'lon': -5.9937435,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:postcode': '41002',
#     'addr:street': 'Alameda de Hércules',
#     'amenity': 'restaurant',
#     'name': 'Churrería y Freiduría Victoria',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 3234791246,
#    'lat': 37.3979082,
#    'lon': -5.9921537,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '35',
#     'addr:postcode': '41002',
#     'addr:street': 'Calle Correduría',
#     'amenity': 'restaurant',
#     'email': 'info@bierkraft.es',
#     'name': 'Bierkraft',
#     'phone': '+34 655 83 45 60'}},
#   {'type': 'node',
#    'id': 3234796096,
#    'lat': 37.3978891,
#    'lon': -5.9919526,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '46',
#     'addr:postcode': '41002',
#     'addr:street': 'Calle Correduría',
#     'amenity': 'restaurant',
#     'contact:facebook': 'https://www.facebook.com/lasushiteka.sevilla',
#     'cuisine': 'japanese',
#     'name': 'Sushi & Brothers',
#     'phone': '+34 955 28 83 54'}},
#   {'type': 'node',
#    'id': 3234801193,
#    'lat': 37.3977442,
#    'lon': -5.9922503,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '38',
#     'addr:postcode': '41002',
#     'addr:street': 'Calle Correduría',
#     'amenity': 'restaurant',
#     'cuisine': 'burger',
#     'name': 'HOB. House of Burger',
#     'website': 'http://houseofburger.es/'}},
#   {'type': 'node',
#    'id': 3366644371,
#    'lat': 37.399585,
#    'lon': 140.3668442,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'japanese', 'name': 'むぎの里'}},
#   {'type': 'node',
#    'id': 3366644373,
#    'lat': 37.3995643,
#    'lon': 140.3665184,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'japanese', 'name': 'やまなか屋'}},
#   {'type': 'node',
#    'id': 3366663224,
#    'lat': 37.3995705,
#    'lon': 140.3650963,
#    'tags': {'amenity': 'restaurant', 'name': 'ホルモン食堂'}},
#   {'type': 'node',
#    'id': 3412442550,
#    'lat': 37.3997436,
#    'lon': -5.9844161,
#    'tags': {'addr:housenumber': '2',
#     'addr:street': 'Ronda de Capuchinos',
#     'amenity': 'restaurant',
#     'cuisine': 'pizza',
#     'name': "Domino's Pizza"}},
#   {'type': 'node',
#    'id': 3469996257,
#    'lat': 37.3985066,
#    'lon': 24.8786134,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'greek'}},
#   {'type': 'node',
#    'id': 3491318892,
#    'lat': 37.3982484,
#    'lon': 140.3821954,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'japanese', 'name': 'とんかつ世界'}},
#   {'type': 'node',
#    'id': 3491328822,
#    'lat': 37.3975582,
#    'lon': 140.3859004,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'japanese', 'name': '源氏'}},
#   {'type': 'node',
#    'id': 3493064591,
#    'lat': 37.3975709,
#    'lon': 140.384481,
#    'tags': {'amenity': 'restaurant',
#     'delivery': 'no',
#     'name': 'ウイングガーデン ロイヤル郡山店'}},
#   {'type': 'node',
#    'id': 3493090531,
#    'lat': 37.397305,
#    'lon': 140.3820836,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'japanese',
#     'name': '水國',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 3493100537,
#    'lat': 37.3995798,
#    'lon': 140.3875886,
#    'tags': {'amenity': 'restaurant', 'name': 'お好み焼いぶき'}},
#   {'type': 'node',
#    'id': 3494775993,
#    'lat': 37.397072,
#    'lon': 127.1131806,
#    'tags': {'amenity': 'restaurant',
#     'name': 'California Pizza Kitchen',
#     'name:ko': 'California Pizza Kitchen'}},
#   {'type': 'node',
#    'id': 3530912785,
#    'lat': 37.3979042,
#    'lon': 140.3830927,
#    'tags': {'addr:full': '福島県郡山市中町8?2?',
#     'amenity': 'restaurant',
#     'image': 'http://images.koriyama.io/20150516/1431756702.jpg',
#     'name': 'コタン',
#     'phone': '024-932-5176'}},
#   {'type': 'node',
#    'id': 3530912786,
#    'lat': 37.3983237,
#    'lon': 140.3837471,
#    'tags': {'addr:full': '福島県郡山市中町１０-３ 一力ビル 1F',
#     'amenity': 'restaurant',
#     'image': 'http://images.koriyama.io/20150516/1431743554.jpg',
#     'name': 'サラダの店 赤とんぼ',
#     'phone': '024-933-9556'}},
#   {'type': 'node',
#    'id': 3530915511,
#    'lat': 37.3992594,
#    'lon': 140.3786617,
#    'tags': {'addr:full': '福島県郡山市虎丸町２１?６?',
#     'amenity': 'restaurant',
#     'image': 'http://images.koriyama.io/20150516/1431755540.jpg',
#     'name': '赤津',
#     'phone': '024-922-9160'}},
#   {'type': 'node',
#    'id': 3530915515,
#    'lat': 37.3978464,
#    'lon': 140.3859251,
#    'tags': {'addr:full': '福島県郡山市駅前１?５?６',
#     'amenity': 'restaurant',
#     'image': 'http://images.koriyama.io/20150516/1431746266.jpg',
#     'name': '魚紋',
#     'phone': '024-938-3343'}},
#   {'type': 'node',
#    'id': 3530949687,
#    'lat': 37.3994612,
#    'lon': 140.3875042,
#    'tags': {'addr:full': '福島県郡山市駅前２丁目５?９',
#     'amenity': 'restaurant',
#     'image': 'http://images.koriyama.io/20150516/1431745079.jpg',
#     'name': 'IEYASU',
#     'phone': '024-954-4434',
#     'website': 'http://ieyasu-noodle.com/'}},
#   {'type': 'node',
#    'id': 3530953193,
#    'lat': 37.3989753,
#    'lon': 140.3874218,
#    'tags': {'addr:full': '福島県郡山市駅前２丁目５?１３',
#     'amenity': 'restaurant',
#     'image': 'http://images.koriyama.io/20150516/1431744789.jpg',
#     'name': 'とんかつ たかの',
#     'phone': '024-932-6360'}},
#   {'type': 'node',
#    'id': 3530953208,
#    'lat': 37.3992097,
#    'lon': 140.386837,
#    'tags': {'addr:full': '福島県郡山市駅前２丁目６?４ 富士館ビル 1F',
#     'amenity': 'restaurant',
#     'image': 'http://images.koriyama.io/20150516/1431746719.jpg',
#     'name': 'プチグリーン',
#     'phone': '024-934-8899',
#     'website': 'http://www.green-co.jp/'}},
#   {'type': 'node',
#    'id': 3530953217,
#    'lat': 37.3988176,
#    'lon': 140.3851848,
#    'tags': {'addr:full': '福島県郡山市大町１丁目３?６',
#     'amenity': 'restaurant',
#     'image': 'http://images.koriyama.io/20150516/1431752653.jpg',
#     'name': '包龍',
#     'phone': '024-925-2315'}},
#   {'type': 'node',
#    'id': 3530953222,
#    'lat': 37.3982423,
#    'lon': 140.3856032,
#    'tags': {'addr:full': '福島県郡山市大町１丁目３?１３',
#     'amenity': 'restaurant',
#     'image': 'http://images.koriyama.io/20150516/1431751024.jpg',
#     'name': '御食事処 三松会館'}},
#   {'type': 'node',
#    'id': 3530953230,
#    'lat': 37.3995549,
#    'lon': 140.3864937,
#    'tags': {'addr:full': '福島県郡山市駅前２丁目７?６',
#     'amenity': 'restaurant',
#     'image': 'http://images.koriyama.io/20150516/1431749859.jpg',
#     'name': '江戸前 春鮨',
#     'phone': '024-932-8709'}},
#   {'type': 'node',
#    'id': 3530953232,
#    'lat': 37.3987963,
#    'lon': 140.3860914,
#    'tags': {'addr:full': '福島県郡山市駅前２丁目７?１９',
#     'amenity': 'restaurant',
#     'image': 'http://images.koriyama.io/20150516/1431746345.jpg',
#     'name': '珍満',
#     'phone': '0120-218-051',
#     'website': 'http://www.kknet.com/chinman/'}},
#   {'type': 'node',
#    'id': 3530966842,
#    'lat': 37.3973135,
#    'lon': 140.3831128,
#    'tags': {'addr:full': '福島県 郡山市 中町 6-14',
#     'amenity': 'restaurant',
#     'image': 'http://images.koriyama.io/20150516/1431750209.jpg',
#     'name': '澤上商店',
#     'phone': '024-983-0606',
#     'website': 'https://tabelog.com/fukushima/A0702/A070201/7009511/'}},
#   {'type': 'node',
#    'id': 3530966843,
#    'lat': 37.3980345,
#    'lon': 140.3789826,
#    'tags': {'amenity': 'restaurant',
#     'image': 'http://images.koriyama.io/20150516/1431752397.jpg',
#     'name': '義王城'}},
#   {'type': 'node',
#    'id': 3530976143,
#    'lat': 37.3955431,
#    'lon': 140.3803461,
#    'tags': {'addr:full': '福島県郡山市堂前町14-1',
#     'amenity': 'restaurant',
#     'image': 'http://images.koriyama.io/20150516/1431744710.jpg',
#     'name': '御食事処不二家',
#     'phone': '024-922-1150',
#     'website': 'https://tabelog.com/fukushima/A0702/A070201/7003941/'}},
#   {'type': 'node',
#    'id': 3544531211,
#    'lat': 37.3971446,
#    'lon': 140.3842383,
#    'tags': {'addr:full': '福島県郡山市仲町12-2',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'カプリチョーザ 郡山中町店',
#     'phone': '024-923-7188'}},
#   {'type': 'node',
#    'id': 3725512509,
#    'lat': 37.3966659,
#    'lon': -122.061578,
#    'tags': {'addr:city': 'Mountain View',
#     'addr:housenumber': '225-2',
#     'addr:postcode': '94043',
#     'addr:state': 'CA',
#     'addr:street': 'East Middlefield Road',
#     'amenity': 'restaurant',
#     'cuisine': 'asian',
#     'delivery': 'yes',
#     'name': 'Khao Kang Thai Kitchen',
#     'phone': '+1 650-960-7100',
#     'takeaway': 'yes',
#     'website': 'https://www.khaokang.com/'}},
#   {'type': 'node',
#    'id': 3725512510,
#    'lat': 37.397335,
#    'lon': -122.0611786,
#    'tags': {'addr:city': 'Mountain View',
#     'addr:housenumber': '235',
#     'addr:postcode': '94043',
#     'addr:state': 'CA',
#     'addr:street': 'East Middlefield Road',
#     'amenity': 'restaurant',
#     'cuisine': 'mexican',
#     'name': 'La Costeña',
#     'outdoor_seating': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 3764833760,
#    'lat': 37.396619,
#    'lon': -122.0613691,
#    'tags': {'addr:city': 'Mountain View',
#     'addr:housenumber': '225-1B',
#     'addr:postcode': '94043',
#     'addr:state': 'CA',
#     'addr:street': 'E Middlefield Rd',
#     'amenity': 'restaurant',
#     'cuisine': 'sushi',
#     'name': 'Joy Sushi',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 3781475865,
#    'lat': 37.3982412,
#    'lon': 140.3731734,
#    'tags': {'amenity': 'restaurant', 'name': 'ピーシーズ', 'name:en': 'pisces'}},
#   {'type': 'node',
#    'id': 3823156105,
#    'lat': 37.3962526,
#    'lon': -5.9731595,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '11',
#     'addr:postcode': '41008',
#     'addr:street': 'Calle Doctor Pedro Vallina',
#     'amenity': 'restaurant',
#     'cuisine': 'argentinian',
#     'name': "Parrilla Argentina Malambo's",
#     'phone': '+34 954 53 27 70',
#     'smoking': 'outside',
#     'website': 'https://restaurantemalambos.es'}},
#   {'type': 'node',
#    'id': 3884323459,
#    'lat': 37.3960296,
#    'lon': 41.3933501,
#    'tags': {'addr:city': 'Midyat/Mardin',
#     'amenity': 'restaurant',
#     'name': 'Divan Lokanta'}},
#   {'type': 'node',
#    'id': 4115899389,
#    'lat': 37.3978965,
#    'lon': -5.9934411,
#    'tags': {'addr:housenumber': '85',
#     'addr:street': 'Alameda de Hércules',
#     'amenity': 'restaurant',
#     'cuisine': 'tapas;spanish',
#     'diet:vegan': 'yes',
#     'internet_access': 'wlan',
#     'name': 'Arte y Sabor'}},
#   {'type': 'node',
#    'id': 4157898660,
#    'lat': 37.3979145,
#    'lon': -5.989301,
#    'tags': {'amenity': 'restaurant', 'name': 'El Coco Verde'}},
#   {'type': 'node',
#    'id': 4157928393,
#    'lat': 37.3997612,
#    'lon': -5.9941155,
#    'tags': {'amenity': 'restaurant', 'name': 'Parilla de Badulaque'}},
#   {'type': 'node',
#    'id': 4158087194,
#    'lat': 37.3974184,
#    'lon': -5.9944434,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Las Columnas',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 4158087195,
#    'lat': 37.3971946,
#    'lon': -5.9944856,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'diet:vegan': 'yes',
#     'name': 'Al Solito Posto'}},
#   {'type': 'node',
#    'id': 4159848073,
#    'lat': 37.3963157,
#    'lon': -5.9945642,
#    'tags': {'amenity': 'restaurant', 'name': 'La Dalia'}},
#   {'type': 'node',
#    'id': 4317198819,
#    'lat': 37.3955682,
#    'lon': 126.6510945,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'thai',
#     'name': 'St Augustin'}},
#   {'type': 'node',
#    'id': 4317774921,
#    'lat': 37.3960191,
#    'lon': 127.1133198,
#    'tags': {'addr:city': '성남시 (Seongnam)',
#     'addr:housenumber': '58',
#     'addr:postcode': '13525',
#     'addr:street': '대왕판교로606번길 (Daewangpangyo-ro 606beon-gil)',
#     'amenity': 'restaurant',
#     'level': '1',
#     'name': '서브웨이',
#     'name:ja': 'スターバックス',
#     'payment:american_express': 'yes',
#     'payment:coins': 'yes',
#     'payment:diners_club': 'yes',
#     'payment:discover_card': 'yes',
#     'payment:jcb': 'yes',
#     'payment:mastercard': 'yes',
#     'payment:notes': 'yes',
#     'payment:unionpay': 'yes',
#     'payment:visa': 'yes',
#     'phone': '+82 31 8016 5666',
#     'smoking': 'no'}},
#   {'type': 'node',
#    'id': 4321082823,
#    'lat': 37.3980717,
#    'lon': -1.9502784,
#    'tags': {'addr:city': 'Huercal-Overa',
#     'addr:postcode': '04600',
#     'addr:street': 'Travesía de la Alameda',
#     'amenity': 'restaurant',
#     'name': 'Estación de Autobuses',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 4321570489,
#    'lat': 37.3954672,
#    'lon': -5.9752118,
#    'tags': {'amenity': 'restaurant', 'name': 'Manila'}},
#   {'type': 'node',
#    'id': 4330309391,
#    'lat': 37.3969362,
#    'lon': -122.023341,
#    'tags': {'addr:housenumber': '821',
#     'addr:street': 'Borregas Avenue',
#     'amenity': 'restaurant',
#     'cuisine': 'mexican',
#     'name': "Ruby's Taqueria"}},
#   {'type': 'node',
#    'id': 4333636077,
#    'lat': 37.3981957,
#    'lon': -1.9416857,
#    'tags': {'addr:city': 'Huercal-Overa',
#     'addr:postcode': '04600',
#     'addr:street': 'Avenida de Guillermo Reina',
#     'amenity': 'restaurant',
#     'cuisine': 'regional',
#     'name': 'La Esencia - cocina con amor',
#     'smoking': 'outside',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 4333655825,
#    'lat': 37.3982621,
#    'lon': -1.9425583,
#    'tags': {'addr:city': 'Huercal-Overa',
#     'addr:postcode': '04600',
#     'addr:street': 'Avenida de Guillermo Reina',
#     'amenity': 'restaurant',
#     'cuisine': 'regional',
#     'name': 'AKALA MAMA',
#     'smoking': 'outside',
#     'takeaway': 'only',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 4391746292,
#    'lat': 37.3967707,
#    'lon': -5.9958972,
#    'tags': {'addr:housenumber': '23',
#     'addr:postcode': '41002',
#     'addr:street': 'Calle Conde Barajas',
#     'amenity': 'restaurant',
#     'cuisine': 'spanish',
#     'name': "D'mercao",
#     'name:es': "D'mercao",
#     'phone': '+34 954389125',
#     'website': 'http://www.dmercao.com'}},
#   {'type': 'node',
#    'id': 4523124708,
#    'lat': 37.3977234,
#    'lon': -5.991412,
#    'tags': {'addr:housenumber': '50',
#     'addr:street': 'Calle Feria',
#     'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': 'La Locanda'}},
#   {'type': 'node',
#    'id': 4583961690,
#    'lat': 37.3977418,
#    'lon': 24.4558166,
#    'tags': {'amenity': 'restaurant',
#     'int_name': 'Taverna O Kantris',
#     'name': 'Ταβερνα Ο Καντρής'}},
#   {'type': 'node',
#    'id': 4608145005,
#    'lat': 37.3978438,
#    'lon': -5.9975647,
#    'tags': {'addr:housenumber': '53',
#     'addr:postcode': '41002',
#     'addr:street': 'Calle Teodosio',
#     'amenity': 'restaurant',
#     'name': 'Antigua Abacería de San Lorenzo',
#     'website': 'http://antiguaabaceriadesanlorenzo.com/'}},
#   {'type': 'node',
#    'id': 4622288971,
#    'lat': 37.395693,
#    'lon': -77.4304832,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'barbecue',
#     'name': 'Prince George Family Barbeque'}},
#   {'type': 'node',
#    'id': 4631098050,
#    'lat': 37.3963696,
#    'lon': 126.9702555,
#    'tags': {'addr:city': '동안구',
#     'addr:housenumber': '관양동883',
#     'addr:postcode': '14057',
#     'addr:street': '시민대로361',
#     'amenity': 'restaurant',
#     'capacity': '40',
#     'cuisine': 'chinese_food',
#     'delivery': 'no',
#     'name': '지향',
#     'name:ko': '지향',
#     'outdoor_seating': 'no',
#     'smoking': 'outside',
#     'takeaway': 'no'}},
#   {'type': 'node',
#    'id': 4631109938,
#    'lat': 37.3965501,
#    'lon': 126.9714645,
#    'tags': {'addr:city': '동안구',
#     'addr:postcode': '14057',
#     'addr:street': '시민대로373',
#     'amenity': 'restaurant',
#     'capacity': '70',
#     'cuisine': '구이전문점',
#     'delivery': 'no',
#     'name': '소야 안양평촌점',
#     'name:ko': '소야 안양평촌점',
#     'outdoor_seating': 'no',
#     'smoking': 'outside'}},
#   {'type': 'node',
#    'id': 4631109940,
#    'lat': 37.3966882,
#    'lon': 126.9702618,
#    'tags': {'amenity': 'restaurant',
#     'capacity': '40',
#     'cuisine': '부대찌개',
#     'delivery': 'no',
#     'name': '대박부대찌개',
#     'name:ko': '대박부대찌개',
#     'outdoor_seating': 'no',
#     'smoking': 'outside',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 4636464406,
#    'lat': 37.3994902,
#    'lon': 127.2536821,
#    'tags': {'amenity': 'restaurant', 'name': '깨순이김밥', 'name:ko': '깨순이김밥'}},
#   {'type': 'node',
#    'id': 4636464407,
#    'lat': 37.3994601,
#    'lon': 127.2537044,
#    'tags': {'amenity': 'restaurant', 'name': '월남선생', 'name:ko': '월남선생'}},
#   {'type': 'node',
#    'id': 4736821421,
#    'lat': 37.3972555,
#    'lon': -5.9913988,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'tapas',
#     'name': 'Lola Por Dios'}},
#   {'type': 'node',
#    'id': 4772750591,
#    'lat': 37.3993524,
#    'lon': 127.2478282,
#    'tags': {'amenity': 'restaurant', 'name': '선릉떡볶이', 'name:ko': '선릉떡볶이'}},
#   {'type': 'node',
#    'id': 4774632339,
#    'lat': 37.3959784,
#    'lon': 127.2343075,
#    'tags': {'amenity': 'restaurant', 'name': '장지리막국수', 'name:ko': '장지리막국수'}},
#   {'type': 'node',
#    'id': 4840775221,
#    'lat': 37.3969398,
#    'lon': 126.6392461,
#    'tags': {'amenity': 'restaurant',
#     'name': '명인 만두',
#     'name:en': 'myong-in mandu'}},
#   {'type': 'node',
#    'id': 4847382768,
#    'lat': 37.3990057,
#    'lon': -5.9847364,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '6A',
#     'addr:postcode': '41003',
#     'addr:street': 'Calle San Hermenegildo',
#     'amenity': 'restaurant',
#     'cuisine': 'pasta',
#     'name': 'El Obrador De Pasta'}},
#   {'type': 'node',
#    'id': 5053385223,
#    'lat': 37.3981574,
#    'lon': 127.1122691,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '김돈이',
#     'name:ko': '김돈이',
#     'phone': '82317060603'}},
#   {'type': 'node',
#    'id': 5053385225,
#    'lat': 37.3978231,
#    'lon': 127.1115199,
#    'tags': {'amenity': 'restaurant', 'name': '판교인생곱창', 'name:ko': '판교인생곱창'}},
#   {'type': 'node',
#    'id': 5059311221,
#    'lat': 37.3973478,
#    'lon': 127.1107916,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'chicken',
#     'name': '교촌치킨',
#     'name:ko': '교촌치킨'}},
#   {'type': 'node',
#    'id': 5059311222,
#    'lat': 37.3976686,
#    'lon': 127.1135864,
#    'tags': {'addr:housenumber': '25 2층',
#     'amenity': 'restaurant',
#     'cuisine': 'steak_house;american',
#     'name': '빕스(2층)',
#     'name:en': 'VIPS',
#     'name:ko': '빕스(2층)'}},
#   {'type': 'node',
#    'id': 5059843834,
#    'lat': 37.3965124,
#    'lon': 127.1107723,
#    'tags': {'amenity': 'restaurant',
#     'name': '미소한우소고기국밥',
#     'name:ko': '미소한우소고기국밥'}},
#   {'type': 'node',
#    'id': 5063668521,
#    'lat': 37.3974682,
#    'lon': 127.1117605,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'chinese',
#     'name': '센트럴차이나 (2층)',
#     'name:en': 'CENTRAL CHINA (2nd fl.)',
#     'name:ko': '센트럴차이나 (2층)'}},
#   {'type': 'node',
#    'id': 5068291724,
#    'lat': 37.3964666,
#    'lon': 127.1099932,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'fish',
#     'name': '연어로먄&도시락',
#     'name:ko': '연어로먄&도시락'}},
#   {'type': 'node',
#    'id': 5073043229,
#    'lat': 37.3971917,
#    'lon': 127.1134615,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '투뿔등심',
#     'name:ko': '투뿔등심'}},
#   {'type': 'node',
#    'id': 5085484632,
#    'lat': 37.3953739,
#    'lon': 127.1091877,
#    'tags': {'amenity': 'restaurant',
#     'name': '현복집(2층 복요리집)',
#     'name:ko': '연복집(2층 복요리집)'}},
#   {'type': 'node',
#    'id': 5085484635,
#    'lat': 37.3973054,
#    'lon': 127.1121307,
#    'tags': {'amenity': 'restaurant', 'name': '도원참치(2층)', 'name:ko': '도원참치'}},
#   {'type': 'node',
#    'id': 5085488323,
#    'lat': 37.3972642,
#    'lon': 127.1124588,
#    'tags': {'amenity': 'restaurant',
#     'name': '포석정(고기구이집 2층)',
#     'name:ko': '포석정(고기구이집 2층)'}},
#   {'type': 'node',
#    'id': 5085622422,
#    'lat': 37.3975716,
#    'lon': 127.1135948,
#    'tags': {'amenity': 'restaurant', 'name': '牛TABLE', 'name:ko': '牛TABLE'}},
#   {'type': 'node',
#    'id': 5085622826,
#    'lat': 37.3976186,
#    'lon': 127.1135937,
#    'tags': {'amenity': 'restaurant', 'name': '속초코다리냉면', 'name:ko': '속초코다리냉면'}},
#   {'type': 'node',
#    'id': 5091320548,
#    'lat': 37.3956659,
#    'lon': 127.1166657,
#    'tags': {'amenity': 'restaurant',
#     'name': '조박사수타짬뽕짜장',
#     'name:ko': '조박사수타짬뽕짜장'}},
#   {'type': 'node',
#    'id': 5096857125,
#    'lat': 37.3974104,
#    'lon': 127.1110148,
#    'tags': {'amenity': 'restaurant',
#     'name': 'IZAKAYA 청담이상(2층)',
#     'name:ko': 'IZAKAYA 청담이상(2층)'}},
#   {'type': 'node',
#    'id': 5096873123,
#    'lat': 37.3974347,
#    'lon': 127.1107972,
#    'tags': {'amenity': 'restaurant',
#     'name': '무명식당(2층)',
#     'name:ko': '무명식당(2층)'}},
#   {'type': 'node',
#    'id': 5096874921,
#    'lat': 37.3957063,
#    'lon': 127.1089876,
#    'tags': {'amenity': 'restaurant',
#     'name': '자산어보(2층)',
#     'name:ko': '자산어보(2층)'}},
#   {'type': 'node',
#    'id': 5125561609,
#    'lat': 37.3996276,
#    'lon': -122.074975,
#    'tags': {'addr:city': 'Mountain View',
#     'addr:housenumber': '400',
#     'addr:postcode': '94043',
#     'addr:state': 'CA',
#     'addr:street': 'Moffett Boulevard',
#     'addr:unit': 'H',
#     'amenity': 'restaurant',
#     'cuisine': 'chinese',
#     'name': 'Chef Zhao Bistro',
#     'outdoor_seating': 'no'}},
#   {'type': 'node',
#    'id': 5126034924,
#    'lat': 37.3964567,
#    'lon': 127.1100122,
#    'tags': {'amenity': 'restaurant',
#     'name': '연어로만&도시락',
#     'name:ko': '연어로만&도시락'}},
#   {'type': 'node',
#    'id': 5127223599,
#    'lat': 37.3980721,
#    'lon': -122.0753192,
#    'tags': {'addr:housenumber': '327D',
#     'addr:street': 'Moffett Boulevard',
#     'alt_name': 'Taqueria 3 Hermanos',
#     'amenity': 'restaurant',
#     'cuisine': 'mexican',
#     'name': 'Taqueria Tres Hermanos',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 5127223604,
#    'lat': 37.3977578,
#    'lon': -122.0760602,
#    'tags': {'addr:housenumber': '311A',
#     'addr:street': 'Moffett Boulevard',
#     'amenity': 'restaurant',
#     'cuisine': 'thai',
#     'name': 'Shana Thai',
#     'opening_hours': 'Mo-Su 11:00-15:00,17:00-22:00',
#     'phone': '+1-650-940-9990',
#     'website': 'https://www.shanathai.com/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 5128324021,
#    'lat': 37.3967639,
#    'lon': 127.113369,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Blooming Garden',
#     'name:ko': 'Blooming Garden'}},
#   {'type': 'node',
#    'id': 5128530721,
#    'lat': 37.3956209,
#    'lon': 127.1136104,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '고봉민김밥',
#     'name:ko': '고봉민김밥'}},
#   {'type': 'node',
#    'id': 5156628427,
#    'lat': 37.3968442,
#    'lon': 127.112643,
#    'tags': {'amenity': 'restaurant',
#     'name': '채선당PLUS(3층)',
#     'name:ko': '채선당PLUS(3층)'}},
#   {'type': 'node',
#    'id': 5286447031,
#    'lat': 37.3983659,
#    'lon': -5.991666,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '61',
#     'addr:postcode': '41002',
#     'addr:street': 'Calle Feria',
#     'amenity': 'restaurant',
#     'description': 'Vegan restaurant with daily menu',
#     'diet:vegan': 'only',
#     'name': 'El Enano Verde',
#     'phone': '+34 646 459717'}},
#   {'type': 'node',
#    'id': 5347945165,
#    'lat': 37.3973472,
#    'lon': -5.9841363,
#    'tags': {'amenity': 'restaurant', 'name': 'El Pelicano'}},
#   {'type': 'node',
#    'id': 5375755637,
#    'lat': 37.3963984,
#    'lon': -5.9939738,
#    'tags': {'amenity': 'restaurant',
#     'brand': 'Wasabi',
#     'brand:wikidata': 'Q23891278',
#     'brand:wikipedia': 'en:Wasabi (restaurant)',
#     'cuisine': 'japanese',
#     'name': 'Wasabi'}},
#   {'type': 'node',
#    'id': 5375755639,
#    'lat': 37.3968228,
#    'lon': -5.9964653,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '1',
#     'addr:postcode': '41002',
#     'addr:street': 'Plaza de San Lorenzo',
#     'amenity': 'restaurant',
#     'email': 'azzaitrestaurante@gmail.com',
#     'name': 'Az-Zait',
#     'phone': '+34954906475',
#     'website': 'http://www.az-zait.es'}},
#   {'type': 'node',
#    'id': 5375755648,
#    'lat': 37.3994151,
#    'lon': -5.9893016,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'tapas',
#     'name': 'La Madriguera De Mai'}},
#   {'type': 'node',
#    'id': 5375755693,
#    'lat': 37.3959785,
#    'lon': -5.9912657,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'japanese',
#     'name': 'La Hermandad De Sushi'}},
#   {'type': 'node',
#    'id': 5384414242,
#    'lat': 37.398534,
#    'lon': -5.9932532,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Al Aljibe',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 5384414256,
#    'lat': 37.3970417,
#    'lon': -5.9937618,
#    'tags': {'amenity': 'restaurant', 'name': 'Carniborea'}},
#   {'type': 'node',
#    'id': 5500247385,
#    'lat': 37.3969014,
#    'lon': 136.9006717,
#    'tags': {'addr:block_number': '朝市通り',
#     'addr:city': '輪島市',
#     'addr:postcode': '928-0001',
#     'addr:province': '石川県',
#     'addr:quarter': '河井町',
#     'amenity': 'restaurant',
#     'name': '饅頭処つかもと'}},
#   {'type': 'node',
#    'id': 5500247387,
#    'lat': 37.3967748,
#    'lon': 136.9007328,
#    'tags': {'addr:block_number': '朝市通り',
#     'addr:city': '輪島市',
#     'addr:housenumber': '91',
#     'addr:neighbourhood': '１部',
#     'addr:postcode': '928-0001',
#     'addr:province': '石川県',
#     'addr:quarter': '河井町',
#     'amenity': 'restaurant',
#     'description': '地元の方にも大人気。朝市の魚を使っています。',
#     'name': '朝市さかば'}},
#   {'type': 'node',
#    'id': 5500247880,
#    'lat': 37.3953479,
#    'lon': 136.9024926,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'japanese;regional',
#     'name': '鷹',
#     'outdoor_seating': 'no'}},
#   {'type': 'node',
#    'id': 5500251928,
#    'lat': 37.3967319,
#    'lon': 136.9000896,
#    'tags': {'amenity': 'restaurant', 'name': '天ぷら\u3000いち富'}},
#   {'type': 'node',
#    'id': 5502027249,
#    'lat': 37.3966203,
#    'lon': 136.9013162,
#    'tags': {'amenity': 'restaurant', 'name': '香華園'}},
#   {'type': 'node',
#    'id': 5502069176,
#    'lat': 37.3962748,
#    'lon': 136.9021917,
#    'tags': {'amenity': 'restaurant', 'name': 'ココだけ！屋'}},
#   {'type': 'node',
#    'id': 5502073633,
#    'lat': 37.3964144,
#    'lon': 136.9018363,
#    'tags': {'amenity': 'restaurant', 'name': 'セレクトフード\u3000のと×能登'}},
#   {'type': 'node',
#    'id': 5502298713,
#    'lat': 37.3955713,
#    'lon': 136.9092352,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': '焼き肉',
#     'delivery': 'no',
#     'name': '焼き肉花じゅん',
#     'outdoor_seating': 'no'}},
#   {'type': 'node',
#    'id': 5507712414,
#    'lat': 37.3957887,
#    'lon': 136.9041234,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'regional;japanese',
#     'name': 'まだら館',
#     'outdoor_seating': 'no'}},
#   {'type': 'node',
#    'id': 5518503519,
#    'lat': 37.3963056,
#    'lon': 136.8999963,
#    'tags': {'amenity': 'restaurant', 'name': 'お食事処\u3000まつおか'}},
#   {'type': 'node',
#    'id': 5543095053,
#    'lat': 37.3985158,
#    'lon': -79.2238243,
#    'tags': {'addr:unit': 'G701',
#     'amenity': 'restaurant',
#     'brand': 'CAVA',
#     'brand:wikidata': 'Q85751038',
#     'cuisine': 'mediterranean',
#     'name': 'CAVA',
#     'opening_hours': 'Mo-Su 10:45-22:00'}},
#   {'type': 'node',
#    'id': 5591929014,
#    'lat': 37.3967299,
#    'lon': 136.9049639,
#    'tags': {'amenity': 'restaurant', 'name': 'あまぶえ'}},
#   {'type': 'node',
#    'id': 5591929018,
#    'lat': 37.3967115,
#    'lon': 136.904889,
#    'tags': {'amenity': 'restaurant', 'name': 'るふぃ'}},
#   {'type': 'node',
#    'id': 5613120921,
#    'lat': 37.3968278,
#    'lon': 127.234109,
#    'tags': {'amenity': 'restaurant', 'name': '장지리해장국', 'name:ko': '장지리해장국'}},
#   {'type': 'node',
#    'id': 5613641595,
#    'lat': 37.3985798,
#    'lon': -3.528826,
#    'tags': {'addr:city': 'Iznalloz',
#     'addr:housenumber': '33',
#     'addr:postcode': '18550',
#     'addr:street': 'Calle Explanada de la Estación',
#     'amenity': 'restaurant',
#     'name': 'Las Mimbres',
#     'phone': '+34 958 38 45 27'}},
#   {'type': 'node',
#    'id': 5649472735,
#    'lat': 37.3965617,
#    'lon': 127.1101644,
#    'tags': {'amenity': 'restaurant', 'name': '대게나라', 'name:ko': '대게나라'}},
#   {'type': 'node',
#    'id': 5659970672,
#    'lat': 37.3966547,
#    'lon': -121.8900749,
#    'tags': {'addr:city': 'San Jose',
#     'addr:housenumber': '2050',
#     'addr:postcode': '95131',
#     'addr:state': 'CA',
#     'addr:street': 'Concourse Drive',
#     'addr:unit': '12',
#     'alt_name': 'Phở Ý Lundy',
#     'alt_name:vi': 'Phở Ý #1',
#     'amenity': 'restaurant',
#     'cuisine': 'vietnamese;soup;bánh_xèo;bánh_cuốn',
#     'name': 'Phở Ý #1',
#     'name:vi': 'Phở Ý #1',
#     'outdoor_seating': 'no',
#     'phone': '+1-408-526-0880',
#     'smoking': 'no',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 5659970675,
#    'lat': 37.3966807,
#    'lon': -121.889538,
#    'tags': {'addr:city': 'San Jose',
#     'addr:housenumber': '2092',
#     'addr:postcode': '95131',
#     'addr:state': 'CA',
#     'addr:street': 'Concourse Drive',
#     'addr:unit': '1',
#     'amenity': 'restaurant',
#     'cuisine': 'chinese',
#     'name': 'Tai Kee Wonton;戴記扁食',
#     'name:en': 'Tai Kee Wonton',
#     'name:zh': '戴記扁食',
#     'phone': '+1-408-432-8889',
#     'website': 'https://taikeewonton.com/home'}},
#   {'type': 'node',
#    'id': 5743394322,
#    'lat': 37.3976696,
#    'lon': -5.9951168,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'chinese',
#     'name': 'Palacio Oriental'}},
#   {'type': 'node',
#    'id': 5762155653,
#    'lat': 37.3966401,
#    'lon': -5.9945812,
#    'tags': {'amenity': 'restaurant', 'name': 'Al Sultan'}},
#   {'type': 'node',
#    'id': 5779542834,
#    'lat': 37.3995833,
#    'lon': -5.991326,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:postcode': '41003',
#     'addr:street': 'Calle Calderón de la Barca',
#     'amenity': 'restaurant',
#     'cuisine': 'burger',
#     'name': 'Atticus Finch',
#     'opening_hours': 'Tu-Sa 13:30-16:00, 20:30-23:15; Su 13:30-16:00',
#     'outdoor_seating': 'yes',
#     'phone': '+34 639 672 014'}},
#   {'type': 'node',
#    'id': 5979892685,
#    'lat': 37.3976224,
#    'lon': 24.8811597,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'greek',
#     'name': 'Mare Calmo'}},
#   {'type': 'node',
#    'id': 6090301685,
#    'lat': 37.3965059,
#    'lon': 31.8630109,
#    'tags': {'amenity': 'restaurant', 'name': 'Reha Et Mangal'}},
#   {'type': 'node',
#    'id': 6282974603,
#    'lat': 37.3987443,
#    'lon': -5.9942444,
#    'tags': {'amenity': 'restaurant', 'name': 'Blossom'}},
#   {'type': 'node',
#    'id': 6494555785,
#    'lat': 37.3981845,
#    'lon': -5.9799264,
#    'tags': {'addr:housenumber': '10 Local 3',
#     'addr:postcode': '41008',
#     'addr:street': 'Calle Carretera de Carmona',
#     'amenity': 'restaurant',
#     'diet:vegan': 'yes',
#     'diet:vegetarian': 'yes',
#     'email': 'hola@verdetariano.com',
#     'name': 'Verdetariano',
#     'opening_hours': 'Mo-Sa 09:30-16:00',
#     'phone': '+34 620049814',
#     'website': 'http://www.verdetariano.com/'}},
#   {'type': 'node',
#    'id': 6497102360,
#    'lat': 37.3985993,
#    'lon': -6.0302819,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'pizza',
#     'name': 'Express Vip Pizzas Camas'}},
#   {'type': 'node',
#    'id': 6500087297,
#    'lat': 37.3982303,
#    'lon': -5.9877997,
#    'tags': {'addr:housenumber': '46',
#     'addr:street': 'Calle San Luis',
#     'amenity': 'restaurant',
#     'email': 'info@koktucocina.com',
#     'name': 'Kok Tu Cocina',
#     'opening_hours': 'Tu-Su 10:00-16:00'}},
#   {'type': 'node',
#    'id': 6500125017,
#    'lat': 37.3970451,
#    'lon': -5.9976175,
#    'tags': {'amenity': 'restaurant', 'name': 'Bodega San Lorenzo'}},
#   {'type': 'node',
#    'id': 6500128339,
#    'lat': 37.3973605,
#    'lon': -5.9975381,
#    'tags': {'amenity': 'restaurant', 'name': 'LaLola'}},
#   {'type': 'node',
#    'id': 6552938386,
#    'lat': 37.3990574,
#    'lon': -5.9756442,
#    'tags': {'amenity': 'restaurant', 'name': 'La Rosaleda'}},
#   {'type': 'node',
#    'id': 7006624613,
#    'lat': 37.3959945,
#    'lon': -6.1394168,
#    'tags': {'amenity': 'restaurant', 'name': 'Taberna El mellizo'}},
#   {'type': 'node',
#    'id': 7050451654,
#    'lat': 37.3970317,
#    'lon': 126.7160461,
#    'tags': {'amenity': 'restaurant',
#     'opening_hours': 'Mo-Su 07:00-21:00',
#     'phone': '422-9295'}},
#   {'type': 'node',
#    'id': 7065238689,
#    'lat': 37.3958355,
#    'lon': -79.9105493,
#    'tags': {'addr:city': 'Daleville',
#     'addr:housenumber': '120',
#     'addr:postcode': '24083',
#     'addr:state': 'VA',
#     'addr:street': 'Kingston Drive',
#     'amenity': 'restaurant',
#     'cuisine': 'barbecue',
#     'name': "Three Li'l Pigs BBQ",
#     'phone': '+1-540-966-0165'}},
#   {'type': 'node',
#    'id': 7141773982,
#    'lat': 37.3962581,
#    'lon': -121.873615,
#    'tags': {'addr:city': 'San Jose',
#     'addr:housenumber': '1631',
#     'addr:postcode': '95132',
#     'addr:state': 'CA',
#     'addr:street': 'North Capitol Avenue',
#     'amenity': 'restaurant',
#     'cuisine': 'vietnamese',
#     'name': 'Pho Dao Restaurant'}},
#   {'type': 'node',
#    'id': 7236208364,
#    'lat': 37.3994435,
#    'lon': -121.8482732,
#    'tags': {'amenity': 'restaurant',
#     'brand': 'Pizza Hut',
#     'brand:wikidata': 'Q191615',
#     'brand:wikipedia': 'en:Pizza Hut',
#     'cuisine': 'pizza',
#     'name': 'Pizza Hut'}},
#   {'type': 'node',
#    'id': 7729826589,
#    'lat': 37.3980215,
#    'lon': 140.3632515,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'italian;fried_pizza',
#     'name': 'La Cuccuma'}},
#   {'type': 'node',
#    'id': 7733373001,
#    'lat': 37.3995005,
#    'lon': 140.3533562,
#    'tags': {'amenity': 'restaurant',
#     'brand': 'バーミヤン',
#     'brand:en': 'Skylark',
#     'brand:ja': 'バーミヤン',
#     'brand:wikidata': 'Q11253593',
#     'brand:wikipedia': 'ja:すかいらーく',
#     'cuisine': 'chinese',
#     'delivery': 'yes',
#     'name': 'バーミヤン',
#     'name:en': 'Skylark',
#     'name:ja': 'バーミヤン',
#     'takeaway': '可'}},
#   {'type': 'node',
#    'id': 8053644006,
#    'lat': 37.3987227,
#    'lon': 126.7390252,
#    'tags': {'amenity': 'restaurant', 'name': '미순네'}},
#   {'type': 'node',
#    'id': 8053662986,
#    'lat': 37.3982368,
#    'lon': 126.7382957,
#    'tags': {'amenity': 'restaurant', 'name': '호남조개구이(회)'}},
#   {'type': 'node',
#    'id': 8053687887,
#    'lat': 37.3985812,
#    'lon': 126.7391678,
#    'tags': {'amenity': 'restaurant', 'name': '소래조개24시'}},
#   {'type': 'node',
#    'id': 8055068385,
#    'lat': 37.3993542,
#    'lon': 126.7398698,
#    'tags': {'amenity': 'restaurant', 'name': '충남회센터'}},
#   {'type': 'node',
#    'id': 8055720785,
#    'lat': 37.3996217,
#    'lon': 126.740694,
#    'tags': {'amenity': 'restaurant', 'name': '명성노래방3F           왕대방조개구이'}},
#   {'type': 'node',
#    'id': 8616930170,
#    'lat': 37.3966079,
#    'lon': -121.8892492,
#    'tags': {'addr:city': 'San Jose',
#     'addr:housenumber': '2092',
#     'addr:postcode': '95131',
#     'addr:state': 'CA',
#     'addr:street': 'Concourse Drive',
#     'amenity': 'restaurant',
#     'cuisine': 'nepalese;indian',
#     'fixme': 'Somewhere in this building',
#     'name': 'Everest Cuisine',
#     'official_name': 'Everest Cuisine San Jose',
#     'operator': 'Om Ganapati Incorporated',
#     'website': 'https://neweverestcuisine.com/'}},
#   {'type': 'node',
#    'id': 8633686307,
#    'lat': 37.3989297,
#    'lon': -79.2090606,
#    'tags': {'addr:city': 'Lynchburg',
#     'addr:housenumber': '2225',
#     'addr:postcode': '24502',
#     'addr:state': 'VA',
#     'addr:street': 'Lakeside Drive',
#     'amenity': 'restaurant',
#     'cuisine': 'barbecue',
#     'fixme': 'unit numbers',
#     'name': 'The Bistro Bros.',
#     'opening_hours': 'Tu-Fr 11:00-19:00',
#     'phone': '+1 434-385-1006',
#     'website': 'http://www.bistrobbq.com/'}},
#   {'type': 'node',
#    'id': 8644108763,
#    'lat': 37.3978075,
#    'lon': 46.2502912,
#    'tags': {'amenity': 'restaurant',
#     'name': 'جگر سرای شبستانه',
#     'phone': '+989396592270'}},
#   {'type': 'node',
#    'id': 8808406892,
#    'lat': 37.3980993,
#    'lon': 126.6656829,
#    'tags': {'addr:city': '동춘1동',
#     'addr:housenumber': '64',
#     'addr:postcode': '21978',
#     'addr:street': '능허대로446번길',
#     'amenity': 'restaurant',
#     'name': '충남집'}},
#   {'type': 'node',
#    'id': 8837948705,
#    'lat': 37.399468,
#    'lon': -5.991109,
#    'tags': {'addr:postcode': '41003',
#     'addr:street': 'Plaza Calderón de la Barca',
#     'addr:unit': 'puesto: 92',
#     'air_conditioning': 'yes',
#     'amenity': 'restaurant',
#     'cuisine': 'italian;asian;venezuelan;brazilian',
#     'delivery': 'yes',
#     'description': 'Gastrobar de comida artesana, fusión con base en panes planos y rellenos como: arepa, focaccia, gyoza, pakora, pita ... Con propuestas con y sin gluten, con carne, vegetarianas y veganas...',
#     'diet:vegan': 'yes',
#     'email': 'condendepanes@gmail.com',
#     'name': 'Condendê',
#     'nohousenumber': 'yes',
#     'opening_hours': 'Tu-Sa 13:00-23:30',
#     'outdoor_seating': 'yes',
#     'payment:cash': 'yes',
#     'payment:debit_cards': 'yes',
#     'payment:maestro': 'yes',
#     'payment:mastercard': 'yes',
#     'payment:visa': 'yes',
#     'payment:visa_electron': 'yes',
#     'phone': '+34 623035530',
#     'takeaway': 'yes',
#     'website': 'https://condende.pedidosweb.es',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 9061416980,
#    'lat': 37.395922,
#    'lon': 127.2142099,
#    'tags': {'amenity': 'restaurant', 'name': '큰손식당'}},
#   {'type': 'node',
#    'id': 9061417000,
#    'lat': 37.3986931,
#    'lon': 127.2085854,
#    'tags': {'amenity': 'restaurant', 'name': '금단식당'}},
#   {'type': 'node',
#    'id': 9092980698,
#    'lat': 37.3960786,
#    'lon': 126.9143674,
#    'tags': {'addr:housenumber': '25',
#     'addr:postcode': '14011',
#     'addr:street': '양화로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '갯마을칼국수보쌈',
#     'phone': '+82 31 469 5597'}},
#   {'type': 'node',
#    'id': 9092980705,
#    'lat': 37.3959668,
#    'lon': 126.9302303,
#    'tags': {'addr:housenumber': '24',
#     'addr:postcode': '14037',
#     'addr:street': '태평로60번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '배부장찌개(안양메가트리아점)',
#     'phone': '+82 31 466 7281'}},
#   {'type': 'node',
#    'id': 9092980708,
#    'lat': 37.3977726,
#    'lon': 126.932736,
#    'tags': {'addr:housenumber': '76',
# ...
#   {'type': 'node',
#    'id': 9093013538,
#    'lat': 37.3967921,
#    'lon': 126.9238407,
#    'tags': {'addr:housenumber': '26',
#     'addr:postcode': '13996',
#     'addr:street': '장내로140번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '영희네쌈밥',
#     'phone': '+82 31 443 2337'}},
#   {'type': 'node',
#    'id': 9093013548,
#    'lat': 37.3970471,
#    'lon': 126.9188451,
#    'tags': {'addr:housenumber': '12',
#     'addr:postcode': '14002',
#     'addr:street': '냉천로193번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '엄마손콩나물국밥',
#     'phone': '+82 31 442 6900'}},
#   {'type': 'node',
#    'id': 9093013549,
#    'lat': 37.3997494,
#    'lon': 126.922146,
#    'tags': {'addr:housenumber': '20',
#     'addr:postcode': '13992',
#     'addr:street': '안양로304번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '울릉도오징어보쌈',
#     'phone': '+82 31 442 2661'}},
#   {'type': 'node',
#    'id': 9093013552,
#    'lat': 37.398919,
#    'lon': 126.923768,
#    'tags': {'addr:housenumber': '14',
#     'addr:postcode': '13992',
#     'addr:street': '장내로149번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '사조참치',
#     'phone': '+82 31 441 9992'}},
#   {'type': 'node',
#    'id': 9093013554,
#    'lat': 37.3996047,
#    'lon': 126.9183735,
#    'tags': {'addr:housenumber': '31',
#     'addr:postcode': '14006',
#     'addr:street': '안양로323번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '전복향기',
#     'phone': '+82 31 441 9945'}},
#   {'type': 'node',
#    'id': 9093013556,
#    'lat': 37.3995671,
#    'lon': 126.9235822,
#    'tags': {'addr:housenumber': '211',
#     'addr:postcode': '13992',
#     'addr:street': '만안로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '이차돌(안양1번가점)',
#     'phone': '+82 31 441 8911'}},
#   {'type': 'node',
#    'id': 9093013557,
#    'lat': 37.3962368,
#    'lon': 126.9245568,
#    'tags': {'addr:housenumber': '11',
#     'addr:postcode': '13996',
#     'addr:street': '안양로258번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '도깨비시장터',
#     'phone': '+82 31 441 7942'}},
#   {'type': 'node',
#    'id': 9093013561,
#    'lat': 37.3976208,
#    'lon': 126.918208,
#    'tags': {'addr:housenumber': '14',
#     'addr:postcode': '14002',
#     'addr:street': '냉천로203번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '부뚜막중앙족발보쌈',
#     'phone': '+82 31 441 5000'}},
#   {'type': 'node',
#    'id': 9093013574,
#    'lat': 37.3964328,
#    'lon': 126.9308089,
#    'tags': {'addr:housenumber': '42',
#     'addr:postcode': '14037',
#     'addr:street': '태평로60번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '거인감자탕',
#     'phone': '+82 31 427 0970'}},
#   {'type': 'node',
#    'id': 9093013581,
#    'lat': 37.3973809,
#    'lon': 126.9630915,
#    'tags': {'addr:housenumber': '156',
#     'addr:postcode': '14055',
#     'addr:street': '부림로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '죽이야기(안양법원점)',
#     'phone': '+82 31 425 6282'}},
#   {'type': 'node',
#    'id': 9093013584,
#    'lat': 37.3986625,
#    'lon': 126.9690866,
#    'tags': {'addr:housenumber': '118',
#     'addr:postcode': '14057',
#     'addr:street': '벌말로',
#     'amenity': 'restaurant',
#     'name': '상하이',
#     'phone': '+82 31 425 1213'}},
#   {'type': 'node',
#    'id': 9093013587,
#    'lat': 37.3974006,
#    'lon': 126.9631076,
#    'tags': {'addr:housenumber': '156',
#     'addr:postcode': '14055',
#     'addr:street': '부림로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '한송정',
#     'phone': '+82 31 424 8599'}},
#   {'type': 'node',
#    'id': 9093013588,
#    'lat': 37.396834,
#    'lon': 126.9633941,
#    'tags': {'addr:housenumber': '152',
#     'addr:postcode': '14055',
#     'addr:street': '부림로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '더착한코다리',
#     'phone': '+82 31 424 6527'}},
#   {'type': 'node',
#    'id': 9093013597,
#    'lat': 37.3967178,
#    'lon': 126.9716197,
#    'tags': {'addr:housenumber': '373',
#     'addr:postcode': '14057',
#     'addr:street': '시민대로',
#     'amenity': 'restaurant',
#     'cuisine': 'japanese',
#     'name': '청도일식',
#     'phone': '+82 31 422 7676'}},
#   {'type': 'node',
#    'id': 9093013598,
#    'lat': 37.3970276,
#    'lon': 126.9743742,
#    'tags': {'addr:housenumber': '401',
#     'addr:postcode': '14057',
#     'addr:street': '시민대로',
#     'amenity': 'restaurant',
#     'name': '강남면옥평촌점',
#     'phone': '+82 31 422 6888'}},
#   {'type': 'node',
#    'id': 9093013601,
#    'lat': 37.3981052,
#    'lon': 126.9836989,
#    'tags': {'addr:housenumber': '18',
#     'addr:postcode': '16004',
#     'addr:street': '봇들3길',
#     'amenity': 'restaurant',
#     'cuisine': 'japanese',
#     'name': '오이시쿠',
#     'phone': '+82 31 422 5219'}},
#   {'type': 'node',
#    'id': 9093013602,
#    'lat': 37.3986951,
#    'lon': 126.9764076,
#    'tags': {'addr:housenumber': '501',
#     'addr:postcode': '13951',
#     'addr:street': '흥안대로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '맛찬들왕소금구이인덕원점',
#     'phone': '+82 31 422 3592'}},
#   {'type': 'node',
#    'id': 9093013605,
#    'lat': 37.3990282,
#    'lon': 126.9622599,
#    'tags': {'addr:housenumber': '178',
#     'addr:postcode': '14055',
#     'addr:street': '부림로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '아라숯불닭갈비앤쭈꾸미',
#     'phone': '+82 31 422 2472'}},
#   {'type': 'node',
#    'id': 9093013606,
#    'lat': 37.3967126,
#    'lon': 126.9716326,
#    'tags': {'addr:housenumber': '373',
#     'addr:postcode': '14057',
#     'addr:street': '시민대로',
#     'amenity': 'restaurant',
#     'name': '도향',
#     'phone': '+82 31 422 2250'}},
#   {'type': 'node',
#    'id': 9093013608,
#    'lat': 37.3961006,
#    'lon': 126.9646534,
#    'tags': {'addr:housenumber': '311',
#     'addr:postcode': '14055',
#     'addr:street': '시민대로',
#     'amenity': 'restaurant',
#     'cuisine': 'japanese',
#     'name': '청어람참치',
#     'phone': '+82 31 421 9777'}},
#   {'type': 'node',
#    'id': 9093015673,
#    'lat': 37.398229,
#    'lon': 126.8336266,
#    'tags': {'addr:housenumber': '17',
#     'addr:postcode': '14980',
#     'addr:street': '금화로627번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '웰빙식당금이점'}},
#   {'type': 'node',
#    'id': 9093015682,
#    'lat': 37.3987814,
#    'lon': 126.796711,
#    'tags': {'addr:housenumber': '13',
#     'addr:postcode': '14972',
#     'addr:street': '관곡지로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '복사꽃피는집 시흥점'}},
#   {'type': 'node',
#    'id': 9093016663,
#    'lat': 37.3996228,
#    'lon': 126.9220679,
#    'tags': {'addr:housenumber': '18',
#     'addr:postcode': '13992',
#     'addr:street': '안양로304번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '팬텀팬패그안양1번가점',
#     'phone': '+82 31 342 0808'}},
#   {'type': 'node',
#    'id': 9093017718,
#    'lat': 37.3982741,
#    'lon': 126.9245977,
#    'tags': {'addr:housenumber': '154',
#     'addr:postcode': '13996',
#     'addr:street': '장내로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '설악명품원조추어탕',
#     'phone': '+82 31 466 0012'}},
#   {'type': 'node',
#    'id': 9093017753,
#    'lat': 37.3997225,
#    'lon': 126.9702993,
#    'tags': {'addr:housenumber': '126',
#     'addr:postcode': '14057',
#     'addr:street': '벌말로',
#     'amenity': 'restaurant',
#     'cuisine': 'international',
#     'name': '더베로니스레스토랑',
#     'phone': '+82 31 450 3636'}},
#   {'type': 'node',
#    'id': 9093017754,
#    'lat': 37.399696,
#    'lon': 126.9702769,
#    'tags': {'addr:housenumber': '126',
#     'addr:postcode': '14057',
#     'addr:street': '벌말로',
#     'amenity': 'restaurant',
#     'cuisine': 'international',
#     'name': '더스카이 레스토랑',
#     'phone': '+82 31 450 3311'}},
#   {'type': 'node',
#    'id': 9093017757,
#    'lat': 37.397075,
#    'lon': 126.920856,
#    'tags': {'addr:housenumber': '119',
#     'addr:postcode': '14001',
#     'addr:street': '장내로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '원조콩나물비빔밥',
#     'phone': '+82 31 449 7100'}},
#   {'type': 'node',
#    'id': 9093017760,
#    'lat': 37.3974474,
#    'lon': 126.9232821,
#    'tags': {'addr:housenumber': '6',
#     'addr:postcode': '13996',
#     'addr:street': '장내로140번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '인생횟집',
#     'phone': '+82 31 449 5590'}},
#   {'type': 'node',
#    'id': 9093017768,
#    'lat': 37.3979234,
#    'lon': 126.9229282,
#    'tags': {'addr:housenumber': '139',
#     'addr:postcode': '13992',
#     'addr:street': '장내로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '조마루뼈다귀',
#     'phone': '+82 31 447 3966'}},
#   {'type': 'node',
#    'id': 9093017774,
#    'lat': 37.3953482,
#    'lon': 126.923479,
#    'tags': {'addr:housenumber': '38',
#     'addr:postcode': '13999',
#     'addr:street': '삼덕로6번길',
#     'amenity': 'restaurant',
#     'cuisine': 'international',
#     'name': '해도',
#     'phone': '+82 31 446 1177'}},
#   {'type': 'node',
#    'id': 9093017776,
#    'lat': 37.3974736,
#    'lon': 126.9231125,
#    'tags': {'addr:housenumber': '4',
#     'addr:postcode': '13996',
#     'addr:street': '장내로140번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '일랑',
#     'phone': '+82 31 445 7766'}},
#   {'type': 'node',
#    'id': 9093017787,
#    'lat': 37.395798,
#    'lon': 126.9141324,
#    'tags': {'addr:housenumber': '8',
#     'addr:postcode': '14011',
#     'addr:street': '양화로25번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '대양수산',
#     'phone': '+82 31 444 2137'}},
#   {'type': 'node',
#    'id': 9093017792,
#    'lat': 37.3972655,
#    'lon': 126.9137933,
#    'tags': {'addr:housenumber': '42',
#     'addr:postcode': '14007',
#     'addr:street': '양화로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '소문난감자탕토종순대국',
#     'phone': '+82 31 443 6464'}},
#   {'type': 'node',
#    'id': 9093017793,
#    'lat': 37.3993852,
#    'lon': 126.9232447,
#    'tags': {'addr:housenumber': '28',
#     'addr:postcode': '13992',
#     'addr:street': '장내로149번길',
#     'amenity': 'restaurant',
#     'cuisine': 'international',
#     'name': '홍대개미안양점',
#     'phone': '+82 31 443 4545'}},
#   {'type': 'node',
#    'id': 9093017959,
#    'lat': 37.3991518,
#    'lon': 126.9441481,
#    'tags': {'addr:housenumber': '181',
#     'addr:postcode': '13920',
#     'addr:street': '관악대로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '이조성쑥돌밥설렁탕',
#     'phone': '+82 31 386 9966'}},
#   {'type': 'node',
#    'id': 9093017998,
#    'lat': 37.3993419,
#    'lon': 126.9618623,
#    'tags': {'addr:housenumber': '182',
#     'addr:postcode': '14055',
#     'addr:street': '부림로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '착한낙지안양점',
#     'phone': '+82 31 382 55550'}},
#   {'type': 'node',
#    'id': 9093018001,
#    'lat': 37.3980133,
#    'lon': 126.9340674,
#    'tags': {'addr:housenumber': '923',
#     'addr:postcode': '13955',
#     'addr:street': '경수대로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '대동식당',
#     'phone': '+82 31 382 2293'}},
#   {'type': 'node',
#    'id': 9093018048,
#    'lat': 37.3991818,
#    'lon': 126.9222068,
#    'tags': {'addr:housenumber': '34',
#     'addr:postcode': '13992',
#     'addr:street': '장내로139번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '홍가네바지락칼국수',
#     'phone': '+82 13 449 9125'}},
#   {'type': 'node',
#    'id': 9093020722,
#    'lat': 37.3994616,
#    'lon': 127.1232796,
#    'tags': {'addr:housenumber': '48',
#     'addr:postcode': '13523',
#     'addr:street': '성남대로779번길',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '죽이야기(분당이매점)'}},
#   {'type': 'node',
#    'id': 9093020774,
#    'lat': 37.399201,
#    'lon': 127.2536065,
#    'tags': {'addr:housenumber': '111',
#     'addr:postcode': '12778',
#     'addr:street': '역동로',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '흥부족발보쌈',
#     'phone': '+82 507 1442 1478'}},
#   {'type': 'node',
#    'id': 9093021233,
#    'lat': 37.3973327,
#    'lon': 127.1135279,
#    'tags': {'addr:postcode': '13525',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '고반식당판교아뷰느프랑점',
#     'phone': '+82 31 707 5861'}},
#   {'type': 'node',
#    'id': 9093021243,
#    'lat': 37.3973044,
#    'lon': 127.1135833,
#    'tags': {'addr:postcode': '13525',
#     'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': '소호정 판교아브뉴프랑점',
#     'phone': '+82 31 703 1360'}},
#   {'type': 'node',
#    'id': 9128113169,
#    'lat': 37.3986868,
#    'lon': -5.9912367,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '33',
#     'addr:postcode': '41003',
#     'addr:street': 'Calle Palacios Malaver',
#     'amenity': 'restaurant',
#     'cuisine': 'spanish',
#     'name': 'Bodega Mateo Ruiz',
#     'opening_hours': 'Mo-Sa 12:30-16:00 20:30-00:00, Su 12:30-16:00',
#     'opening_hours:covid19': 'restricted'}},
#   {'type': 'node',
#    'id': 9398494828,
#    'lat': 37.3979279,
#    'lon': 27.6553929,
#    'tags': {'amenity': 'restaurant', 'name': 'Onur cheff'}},
#   {'type': 'node',
#    'id': 9469666317,
#    'lat': 37.396598,
#    'lon': -5.9952395,
#    'tags': {'addr:housenumber': '13',
#     'addr:postcode': '41002',
#     'addr:street': 'Calle Conde Barajas',
#     'amenity': 'restaurant',
#     'name': 'La Tienda de la Azotea',
#     'opening_hours': 'Mo-Su 16:30-20:00'}},
#   {'type': 'node',
#    'id': 9519335551,
#    'lat': 37.397032,
#    'lon': 13.6199287,
#    'tags': {'addr:city': 'Aragona',
#     'addr:postcode': '92021',
#     'addr:street': 'Via Salvatore La Rosa',
#     'amenity': 'restaurant',
#     'cuisine': 'pizza',
#     'name': 'Pizzeria Trattoria Olimpia',
#     'phone': '092237171'}},
#   {'type': 'node',
#    'id': 9702779898,
#    'lat': 37.3954377,
#    'lon': 127.29123,
#    'tags': {'amenity': 'restaurant', 'name': '미스터빠삭'}},
#   {'type': 'node',
#    'id': 9702779900,
#    'lat': 37.3967684,
#    'lon': 127.2922057,
#    'tags': {'amenity': 'restaurant', 'name': '화돌농장'}},
#   {'type': 'node',
#    'id': 9702779902,
#    'lat': 37.395625,
#    'lon': 127.2964013,
#    'tags': {'amenity': 'restaurant', 'name': '고향집'}},
#   {'type': 'node',
#    'id': 9780426250,
#    'lat': 37.3956629,
#    'lon': 126.6399131,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'sushi'}},
#   {'type': 'node',
#    'id': 9820975017,
#    'lat': 37.3975401,
#    'lon': -5.993066,
#    'tags': {'amenity': 'restaurant', 'name': 'Coolantro'}},
#   {'type': 'node',
#    'id': 9922811557,
#    'lat': 37.3969694,
#    'lon': 13.3295326,
#    'tags': {'air_conditioning': 'no',
#     'amenity': 'restaurant',
#     'cuisine': 'italian;fish;pizza',
#     'diet:vegan': 'no',
#     'diet:vegetarian': 'yes',
#     'indoor_seating': 'no',
#     'internet_access': 'no',
#     'level': '0',
#     'name': 'Le Tre Terre De Gorgo',
#     'opening_hours': 'Mo-Su 19:30+; PH closed',
#     'outdoor_seating': 'yes',
#     'smoking': 'outside',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 10069278617,
#    'lat': 37.3962871,
#    'lon': -5.9941945,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': 'Mumbai Indian Restaurant'}},
#   {'type': 'node',
#    'id': 10157063397,
#    'lat': 37.3981527,
#    'lon': -5.9854906,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '21',
#     'addr:postcode': '41003',
#     'addr:street': 'Calle Juzgado',
#     'amenity': 'restaurant',
#     'cuisine': 'regional',
#     'email': 'info@paellaehijos.com',
#     'name': 'Paella e Hijos',
#     'phone': '+34 630 14 00 97',
#     'website': 'https://www.paellaehijos.com/'}},
#   {'type': 'node',
#    'id': 10653009111,
#    'lat': 37.3984106,
#    'lon': -5.9879428,
#    'tags': {'addr:street': 'Calle San Luis, 50',
#     'amenity': 'restaurant',
#     'description': 'Restaurante "Slow food"',
#     'name': 'ConTenedor',
#     'phone': '954 916 333',
#     'website': 'https://restaurantecontenedor.com/'}},
#   {'type': 'node',
#    'id': 10715714122,
#    'lat': 37.3963843,
#    'lon': -5.9882966,
#    'tags': {'addr:city': 'Sevilla',
#     'addr:housenumber': '1',
#     'addr:postcode': '41003',
#     'addr:street': 'Calle Maravillas',
#     'amenity': 'restaurant',
#     'email': 'ei@maravillasocialclub.com',
#     'name': 'Maravilla Social Club',
#     'phone': '+34 955 67 20 18',
#     'website': 'https://maravillasocialclub.com/'}},
#   {'type': 'node',
#    'id': 10715714124,
#    'lat': 37.3981117,
#    'lon': -5.9914797,
#    'tags': {'addr:street': 'Calle Feria',
#     'amenity': 'restaurant',
#     'name': 'La Lista Negra',
#     'phone': '666000259'}}]}

# %%
elements = data['elements']
places = {'lat': [], 'lon': [], 'name': [], 'address': []}
for i in elements:
    try:
        latitude = i['lat']
        longitude = i['lon']
        name = i['tags']['name']
        street = i['tags']['addr:street']
        number = i['tags']['addr:housenumber']
        
        
        places['lat'].append(latitude)
        places['lon'].append(longitude)
        places['name'].append(name)
        places['address'].append(street + ' ' + str(number))
        
    except:
        continue

df = pd.DataFrame(places)
df[(df['lon']<-4)&(df['lon']>-7)]
# Out:
#            lat       lon                             name  \
# 0    37.398354 -5.994309                         Pomodoro
# 3    37.396208 -5.974479                 Berenice Bristot
# 4    37.399295 -5.992308                       Gibi Tapas
# 5    37.399596 -5.992796                       La Mata 24
# 11   37.395875 -5.995603                        La Azotea
# 12   37.397908 -5.992154                        Bierkraft
# 13   37.397889 -5.991953                 Sushi & Brothers
# 14   37.397744 -5.992250             HOB. House of Burger
# 15   37.399744 -5.984416                   Domino's Pizza
# 19   37.396253 -5.973160     Parrilla Argentina Malambo's
# 20   37.397897 -5.993441                     Arte y Sabor
# 23   37.396771 -5.995897                         D'mercao
# 24   37.397723 -5.991412                       La Locanda
# 25   37.397844 -5.997565  Antigua Abacería de San Lorenzo
# 27   37.399006 -5.984736              El Obrador De Pasta
# 31   37.398366 -5.991666                   El Enano Verde
# 32   37.396823 -5.996465                          Az-Zait
# 36   37.398184 -5.979926                     Verdetariano
# 37   37.398230 -5.987800                    Kok Tu Cocina
# 98   37.398687 -5.991237                Bodega Mateo Ruiz
# 99   37.396598 -5.995240           La Tienda de la Azotea
# 100  37.398153 -5.985491                   Paella e Hijos
# 101  37.396384 -5.988297            Maravilla Social Club
#
#                                    address
# 0                   Alameda de Hércules 29
# 3                       Calle Samaniego 13
# 4                  Calle Peris Mencheta 21
# 5                            Calle Mata 24
# 11           Calle Jesús del Gran Poder 31
# 12                     Calle Correduría 35
# 13                     Calle Correduría 46
# 14                     Calle Correduría 38
# 15                   Ronda de Capuchinos 2
# 19           Calle Doctor Pedro Vallina 11
# 20                  Alameda de Hércules 85
# 23                  Calle Conde Barajas 23
# 24                          Calle Feria 50
# 25                       Calle Teodosio 53
# 27               Calle San Hermenegildo 6A
# 31                          Calle Feria 61
# 32                  Plaza de San Lorenzo 1
# 36   Calle Carretera de Carmona 10 Local 3
# 37                       Calle San Luis 46
# 98               Calle Palacios Malaver 33
# 99                  Calle Conde Barajas 13
# 100                       Calle Juzgado 21
# 101                     Calle Maravillas 1
