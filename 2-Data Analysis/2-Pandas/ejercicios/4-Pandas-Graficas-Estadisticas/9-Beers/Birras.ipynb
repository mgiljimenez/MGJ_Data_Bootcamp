# %% [markdown]
# ![imagen](https://cdn.foodbeast.com/content/wp-content/uploads/2012/03/beer-print-01-selectism.jpg)
#
# # Ejercicio pandas estadistica
# Para este ejercicio se ha utilizado [un dataset de un concurso de kaggle](https://www.kaggle.com/nickhould/craft-cans), cuyo reto consiste en predecir el tipo de cerveza en función de sus características (nivel de alcohol, amargura, tamaño...).
#
# # Ejercicio 1
# Importa las librerias que consideres

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Ejercicio 2
# 1. Importa el dataset "datasets_beer.csv"
# 2. Imprime por pantalla los primeros registros.
# 3. ¿Cuáles son sus columnas?
# 4. ¿Qué dimensiones tiene el DataFrame?

# %%
dataset=pd.read_csv("data\datasets_beers.csv")
dataset.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'abv', 'ibu', 'id', 'name', 'style', 'brewery_id',
#        'ounces'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2410 non-null   int64
#  1   abv         2348 non-null   float64
#  2   ibu         1405 non-null   float64
#  3   id          2410 non-null   int64
#  4   name        2410 non-null   object
#  5   style       2405 non-null   object
#  6   brewery_id  2410 non-null   int64
#  7   ounces      2410 non-null   float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 150.8+ KB

# %% [markdown]
# ## Ejercicio 3
# [Elimina la columna "Unnamed: 0"](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %%
dataset1=dataset.copy()

# %%
dataset1.drop(columns=["Unnamed: 0"])
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
#       brewery_id  ounces
# 0            408    12.0
# 1            177    12.0
# 2            177    12.0
# 3            177    12.0
# 4            177    12.0
# ...          ...     ...
# 2405         424    12.0
# 2406         424    12.0
# 2407         424    12.0
# 2408         424    12.0
# 2409         424    12.0
#
# [2410 rows x 7 columns]

# %% [markdown]
# ## Ejercicio 4
# ¿Cuántas filas y columnas tiene el dataset?

# %%
print("Filas:", len(dataset))
print("Columnas:", len(dataset.columns))
# Out:
# Filas: 2410
# Columnas: 8

# %% [markdown]
# ## Ejercicio 5
# ¿De qué tipo son los datos?

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2410 non-null   int64
#  1   abv         2348 non-null   float64
#  2   ibu         1405 non-null   float64
#  3   id          2410 non-null   int64
#  4   name        2410 non-null   object
#  5   style       2405 non-null   object
#  6   brewery_id  2410 non-null   int64
#  7   ounces      2410 non-null   float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 150.8+ KB

# %% [markdown]
# ## Ejercicio 6
# Obtén en una nuevo DataFrame un resumen con las principales estadísticas de las columnas numércias: mean, max, count, cuartiles...

# %%
dataset.describe()
# Out:
#         Unnamed: 0          abv          ibu           id   brewery_id  \
# count  2410.000000  2348.000000  1405.000000  2410.000000  2410.000000
# mean   1204.500000     0.059773    42.713167  1431.113278   231.749793
# std     695.851397     0.013542    25.954066   752.459975   157.685604
# min       0.000000     0.001000     4.000000     1.000000     0.000000
# 25%     602.250000     0.050000    21.000000   808.250000    93.000000
# 50%    1204.500000     0.056000    35.000000  1453.500000   205.000000
# 75%    1806.750000     0.067000    64.000000  2075.750000   366.000000
# max    2409.000000     0.128000   138.000000  2692.000000   557.000000
#
#             ounces
# count  2410.000000
# mean     13.592241
# std       2.352204
# min       8.400000
# 25%      12.000000
# 50%      12.000000
# 75%      16.000000
# max      32.000000

# %% [markdown]
# ## Ejercicio 7
# ¿Cuántas birras hay de cada estilo en este dataset? [Investiga en la documentación de Series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html) si puedes hacer un conteo de valores.

# %%
dataset.groupby("style").sum()
# Out:
#                             Unnamed: 0    abv     ibu      id  brewery_id  \
# style
# Abbey Single Ale                  1433  0.098    44.0    4392         114
# Altbier                          14614  0.707   273.0   19252        2860
# American Adjunct Lager           30317  0.877   121.0   30853        2934
# American Amber / Red Ale        152511  7.182  2795.0  169229       32990
# American Amber / Red Lager       38414  1.385   372.0   33478        8873
# ...                                ...    ...     ...     ...         ...
# Tripel                           12710  0.955    94.0   17134        1710
# Vienna Lager                     22226  1.021   341.0   16655        5925
# Wheat Ale                         1337  0.060    24.0    2666           3
# Winter Warmer                    16096  1.056   197.0   21404        3326
# Witbier                          59943  2.624   389.0   67888       13132
#
#                             ounces
# style
# Abbey Single Ale              24.0
# Altbier                      176.0
# American Adjunct Lager       240.0
# American Amber / Red Ale    1768.0
# American Amber / Red Lager   384.0
# ...                            ...
# Tripel                       164.9
# Vienna Lager                 260.0
# Wheat Ale                     16.0
# Winter Warmer                196.0
# Witbier                      680.0
#
# [99 rows x 6 columns]

# %% [markdown]
# ## Ejercicio 8
# 1. Imprime por pantalla los registros del 10 al 20
# 2. De esos registros, imprime por pantalla desde la columna `name` a `ounces`, ambas incluidas
# 3. Quédate con las columnas `abv`, `ibu` y `ounces`, y además quédate sólo con los registros 10 al 20.
# 4. Convierte el resultado del apartado 3 en un array de `numpy`

# %%
dataset2=dataset.iloc[10:21,:].copy()
dataset2
# Out:
#     Unnamed: 0    abv   ibu    id                          name  \
# 10          10  0.072   NaN  2099             Sophomoric Saison
# 11          11  0.073   NaN  2098         Regional Ring Of Fire
# 12          12  0.069   NaN  2097                    Garce Selé
# 13          13  0.085   NaN  1980               Troll Destroyer
# 14          14  0.061  60.0  1979                  Bitter Bitch
# 15          15  0.060   NaN  2318                   Ginja Ninja
# 16          16  0.060   NaN  2170                 Cherried Away
# 17          17  0.060   NaN  2169                  Rhubarbarian
# 18          18  0.060   NaN  1502                   BrightCider
# 19          19  0.082   NaN  1593   He Said Baltic-Style Porter
# 20          20  0.082   NaN  1592  He Said Belgian-Style Tripel
#
#                       style  brewery_id  ounces
# 10   Saison / Farmhouse Ale         177    12.0
# 11   Saison / Farmhouse Ale         177    12.0
# 12   Saison / Farmhouse Ale         177    12.0
# 13              Belgian IPA         177    12.0
# 14  American Pale Ale (APA)         177    12.0
# 15                    Cider         154    12.0
# 16                    Cider         154    12.0
# 17                    Cider         154    12.0
# 18                    Cider         154    12.0
# 19            Baltic Porter         368    12.0
# 20                   Tripel         368    12.0

# %%
dataset2.loc[:,"name":]
# Out:
#                             name                    style  brewery_id  ounces
# 10             Sophomoric Saison   Saison / Farmhouse Ale         177    12.0
# 11         Regional Ring Of Fire   Saison / Farmhouse Ale         177    12.0
# 12                    Garce Selé   Saison / Farmhouse Ale         177    12.0
# 13               Troll Destroyer              Belgian IPA         177    12.0
# 14                  Bitter Bitch  American Pale Ale (APA)         177    12.0
# 15                   Ginja Ninja                    Cider         154    12.0
# 16                 Cherried Away                    Cider         154    12.0
# 17                  Rhubarbarian                    Cider         154    12.0
# 18                   BrightCider                    Cider         154    12.0
# 19   He Said Baltic-Style Porter            Baltic Porter         368    12.0
# 20  He Said Belgian-Style Tripel                   Tripel         368    12.0

# %%
dataset2[["abv","ibu","ounces"]]
# Out:
#       abv   ibu  ounces
# 10  0.072   NaN    12.0
# 11  0.073   NaN    12.0
# 12  0.069   NaN    12.0
# 13  0.085   NaN    12.0
# 14  0.061  60.0    12.0
# 15  0.060   NaN    12.0
# 16  0.060   NaN    12.0
# 17  0.060   NaN    12.0
# 18  0.060   NaN    12.0
# 19  0.082   NaN    12.0
# 20  0.082   NaN    12.0

# %%
np.array(dataset2)
# Out:
# array([[10, 0.072, nan, 2099, 'Sophomoric Saison',
#         'Saison / Farmhouse Ale', 177, 12.0],
#        [11, 0.073, nan, 2098, 'Regional Ring Of Fire',
#         'Saison / Farmhouse Ale', 177, 12.0],
#        [12, 0.069, nan, 2097, 'Garce Selé', 'Saison / Farmhouse Ale',
#         177, 12.0],
#        [13, 0.085, nan, 1980, 'Troll Destroyer', 'Belgian IPA', 177,
#         12.0],
#        [14, 0.061, 60.0, 1979, 'Bitter Bitch', 'American Pale Ale (APA)',
#         177, 12.0],
#        [15, 0.06, nan, 2318, 'Ginja Ninja', 'Cider', 154, 12.0],
#        [16, 0.06, nan, 2170, 'Cherried Away', 'Cider', 154, 12.0],
#        [17, 0.06, nan, 2169, 'Rhubarbarian', 'Cider', 154, 12.0],
#        [18, 0.06, nan, 1502, 'BrightCider', 'Cider', 154, 12.0],
#        [19, 0.0819999999999999, nan, 1593, 'He Said Baltic-Style Porter',
#         'Baltic Porter', 368, 12.0],
#        [20, 0.0819999999999999, nan, 1592,
#         'He Said Belgian-Style Tripel', 'Tripel', 368, 12.0]],
#       dtype=object)

# %% [markdown]
# ## Ejercicio 9
# ¿Cuántas onzas pesan todas las birras del dataset?

# %%
dataset["ounces"].sum()
# Out:
# 32757.3

# %% [markdown]
# ## Ejercicio 10
# El amargor de las cervezas se mide por su nivel de IBUs.
# 1. ¿Cuál es el amargor medio de las cervezas?
# 2. ¿El máximo? ¿Y el mínimo?
# 3. ¿Qué cerveza es la que tiene el amargor máximo? ¿Cuál es la de amargor mínimo?

# %% [markdown]
# dataset.head()

# %%
print("Amargor medio de las cervezas:", dataset["abv"].mean())
print("Amargor máximo de las cervezas:", dataset["abv"].max())
print("Amargor mínimo de las cervezas:", dataset["abv"].min())
# Out:
# Amargor medio de las cervezas: 0.05977342419080067
# Amargor máximo de las cervezas: 0.128
# Amargor mínimo de las cervezas: 0.001

# %%
filtrado=dataset["abv"]==dataset["abv"].max()
dataset[filtrado]
# Out:
#       Unnamed: 0    abv  ibu    id  \
# 2278        2278  0.128  NaN  2565
#
#                                                    name             style  \
# 2278  Lee Hill Series Vol. 5 - Belgian Style Quadrup...  Quadrupel (Quad)
#
#       brewery_id  ounces
# 2278          51    19.2

# %%
filtrado=dataset["abv"]==dataset["abv"].min()
dataset[filtrado]
# Out:
#       Unnamed: 0    abv  ibu   id         name             style  brewery_id  \
# 2266        2266  0.001  NaN  606  Scotty K NA  Low Alcohol Beer         522
#
#       ounces
# 2266    16.0

# %% [markdown]
# ## Ejercicio 11
# No queda muy claro cuánto de dispar, de dispersa, es la medida de IBU. Mediante estadística descriptiva (una o dos métricas, sin gráficas), razona la dispersión de la variable IBU.

# %% [markdown]
# ## Ejercicio 12
# ¿Existe alguna relación lineal entre las variables numéricas del dataset? Intenta pintar este razonmiento mediante un gráfico

# %% [markdown]
# ## Ejercicio 13
# Representa el nivel de alcohol (columna `abv`) en un histograma. ¿Se trata de una distribución simétrica o asimétrica?

# %% [markdown]
# ## Ejercicio 14
# Representa mediante un *boxplot* de `seaborn` la variable `abv`

# %% [markdown]
# ## Ejercicio 15
# 1. ¿Qué estilos son los que tienen en media más alcohol?
# 2. ¿Y los estilos que son en media más amargos?

# %%
dataset.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
dataset.groupby("")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16940\4016373148.py in <module>
# ----> 1 dataset.groupby("")
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7639             squeeze=squeeze,  # type: ignore[arg-type]
#    7640             observed=observed,
# -> 7641             dropna=dropna,
#    7642         )
#    7643
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     895                 observed=observed,
#     896                 mutated=self.mutated,
# --> 897                 dropna=self.dropna,
#     898             )
#     899
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     860                 in_axis, level, gpr = False, gpr, None
#     861             else:
# --> 862                 raise KeyError(gpr)
#     863         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     864             # Add key to exclusions
#
# KeyError: ''

# %% [markdown]
# ## Ejercicio 16
# Carga el datasets de cervecerias `datasets_breweries.csv`

# %%
breweries=pd.read_csv("data\datasets_breweries.csv")

# %% [markdown]
# ## Ejercicio 17
# 1. Renombra la columna `Unnamed: 0` como `brewery_id`
# 2. Renombra tb la columna `name` por `brewery_name`. ¿Puedes hacer ambos apartados en una sola sentencia?

# %%
breweries1=breweries.rename(columns = {'Unnamed: 0':'brewery_id', "name":"brewery_name"})
breweries1
# Out:
#      brewery_id                   brewery_name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 18
# Junta los dos datasets que tienes

# %%
new_df=pd.merge(dataset,breweries1, on="brewery_id")
new_df
# Out:
#       Unnamed: 0    abv   ibu    id                  name  \
# 0              0  0.050   NaN  1436              Pub Beer
# 1              1  0.066   NaN  2265           Devil's Cup
# 2              2  0.071   NaN  2264   Rise of the Phoenix
# 3              3  0.090   NaN  2263              Sinister
# 4              4  0.075   NaN  2262         Sex and Candy
# ...          ...    ...   ...   ...                   ...
# 2405        2405  0.067  45.0   928             Belgorado
# 2406        2406  0.052   NaN   807         Rail Yard Ale
# 2407        2407  0.055   NaN   620       B3K Black Lager
# 2408        2408  0.055  40.0   145   Silverback Pale Ale
# 2409        2409  0.052   NaN    84  Rail Yard Ale (2009)
#
#                                style  brewery_id  ounces  \
# 0                American Pale Lager         408    12.0
# 1            American Pale Ale (APA)         177    12.0
# 2                       American IPA         177    12.0
# 3     American Double / Imperial IPA         177    12.0
# 4                       American IPA         177    12.0
# ...                              ...         ...     ...
# 2405                     Belgian IPA         424    12.0
# 2406        American Amber / Red Ale         424    12.0
# 2407                     Schwarzbier         424    12.0
# 2408         American Pale Ale (APA)         424    12.0
# 2409        American Amber / Red Ale         424    12.0
#
#                    brewery_name    city state
# 0     10 Barrel Brewing Company    Bend    OR
# 1           18th Street Brewery    Gary    IN
# 2           18th Street Brewery    Gary    IN
# 3           18th Street Brewery    Gary    IN
# 4           18th Street Brewery    Gary    IN
# ...                         ...     ...   ...
# 2405    Wynkoop Brewing Company  Denver    CO
# 2406    Wynkoop Brewing Company  Denver    CO
# 2407    Wynkoop Brewing Company  Denver    CO
# 2408    Wynkoop Brewing Company  Denver    CO
# 2409    Wynkoop Brewing Company  Denver    CO
#
# [2410 rows x 11 columns]

# %% [markdown]
# ## Ejercicio 19
# 1. ¿Cuántos estados diferentes hay?
# 2. ¿Y ciudades diferentes?
# 3. ¿Cuántas cervecerías hay?

# %%
print("Total de estados:", len(new_df.groupby("state").count()))
print("Total de ciudades:", len(new_df.groupby("city").count()))
print("Total de estados:", len(new_df.groupby("brewery_name").count()))
# Out:
# Total de estados: 51
# Total de ciudades: 384
# Total de estados: 551

# %% [markdown]
# ## Ejercicio 20
# Agrupa por estado y ciudad, la media, mediana y máximo nivel de alcohol

# %%
new_df.groupby(["state","city"]).describe().copy()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16940\2652107013.py in <module>
# ----> 1 new_df.groupby(["state","city"]).describe().copy()
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\groupby\groupby.py in describe(self, **kwargs)
#    1971     def describe(self, **kwargs):
#    1972         with group_selection_context(self):
# -> 1973             result = self.apply(lambda x: x.describe(**kwargs))
#    1974             if self.axis == 1:
#    1975                 return result.T
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#    1273         with option_context("mode.chained_assignment", None):
#    1274             try:
# -> 1275                 result = self._python_apply_general(f, self._selected_obj)
#    1276             except TypeError:
#    1277                 # gh-20949
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f, data)
#    1307             data after applying f
#    1308         """
# -> 1309         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#    1310
#    1311         return self._wrap_applied_output(
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     813             try:
#     814                 sdata = splitter.sorted_data
# --> 815                 result_values, mutated = splitter.fast_apply(f, sdata, group_keys)
#     816
#     817             except IndexError:
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\groupby\ops.py in fast_apply(self, f, sdata, names)
#    1358         # must return keys::list, values::list, mutated::bool
#    1359         starts, ends = lib.generate_slices(self.slabels, self.ngroups)
# -> 1360         return libreduction.apply_frame_axis0(sdata, f, names, starts, ends)
#    1361
#    1362     def _chop(self, sdata: DataFrame, slice_obj: slice) -> DataFrame:
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\_libs\reduction.pyx in pandas._libs.reduction.apply_frame_axis0()
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#    1971     def describe(self, **kwargs):
#    1972         with group_selection_context(self):
# -> 1973             result = self.apply(lambda x: x.describe(**kwargs))
#    1974             if self.axis == 1:
#    1975                 return result.T
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10027             exclude=exclude,
#   10028             datetime_is_numeric=datetime_is_numeric,
# > 10029             percentiles=percentiles,
#   10030         )
#   10031
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\describe.py in describe_ndframe(obj, include, exclude, datetime_is_numeric, percentiles)
#      93         )
#      94
# ---> 95     result = describer.describe(percentiles=percentiles)
#      96     return cast(FrameOrSeries, result)
#      97
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\describe.py in describe(self, percentiles)
#     179             [x.reindex(col_names, copy=False) for x in ldesc],
#     180             axis=1,
# --> 181             sort=False,
#     182         )
#     183         d.columns = data.columns.copy()
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     305     )
#     306
# --> 307     return op.get_result()
#     308
#     309
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     506
#     507                 index, columns = self.new_axes
# --> 508                 df = cons(data, index=index, copy=self.copy)
#     509                 df.columns = columns
#     510                 return df.__finalize__(self, method="concat")
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     463
#     464     return arrays_to_mgr(
# --> 465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#     467
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     134     if typ == "block":
#     135         return create_block_manager_from_arrays(
# --> 136             arrays, arr_names, axes, consolidate=consolidate
#     137         )
#     138     elif typ == "array":
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes, consolidate)
#    1771
#    1772     try:
# -> 1773         blocks = _form_blocks(arrays, names, axes, consolidate)
#    1774         mgr = BlockManager(blocks, axes)
#    1775     except ValueError as e:
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\internals\managers.py in _form_blocks(arrays, names, axes, consolidate)
#    1837     if len(items_dict["NumericBlock"]):
#    1838         numeric_blocks = _multi_blockify(
# -> 1839             items_dict["NumericBlock"], consolidate=consolidate
#    1840         )
#    1841         blocks.extend(numeric_blocks)
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\internals\managers.py in _multi_blockify(tuples, dtype, consolidate)
#    1927         # Type[complex], Type[bool], Type[object], None]"; expected "dtype[Any]"
#    1928         values, placement = _stack_arrays(
# -> 1929             list(tup_block), dtype  # type: ignore[arg-type]
#    1930         )
#    1931
#
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\internals\managers.py in _stack_arrays(tuples, dtype)
#    1957     stacked = np.empty(shape, dtype=dtype)
#    1958     for i, arr in enumerate(arrays):
# -> 1959         stacked[i] = arr
#    1960
#    1961     return stacked, placement
#
# KeyboardInterrupt:

# %% [markdown]
# ## Ejercicio 21
# ¿Cuáles son las cervezas más amargas que se consumen en Indiana, estado = `IN`?

# %%
filtrado3=(new_df["state"]==" IN")

new_df[filtrado3].sort_values("abv",ascending=False)
# Out:
#       Unnamed: 0    abv    ibu    id  \
# 2189        2189  0.120   90.0  2621
# 2037        2037  0.099   36.0  2083
# 2066        2066  0.099   60.0   394
# 2049        2049  0.099   75.0  1367
# 479          479  0.099  115.0  2471
# ...          ...    ...    ...   ...
# 1625        1625  0.042    NaN  1956
# 945          945  0.042   26.0   439
# 851          851  0.040    NaN  1657
# 2044        2044    NaN    NaN  1948
# 2051        2051    NaN    NaN  1347
#
#                                                   name  \
# 2189                                              Csar
# 2037  Bourbon Barrel Batch 666: Sympathy for the Devil
# 2066                              Johan the Barleywine
# 2049                        Bourbon Barrel Aged Timmie
# 479                                   Hopkick Dropkick
# ...                                                ...
# 1625                           Farmer's Daughter Wheat
# 945                            Great Crescent Mild Ale
# 851                                   Leprechaun Lager
# 2044                                       30 Min Coma
# 2051                            Bourbon Barrel Cowbell
#
#                                style  brewery_id  ounces  \
# 2189          Russian Imperial Stout          17    16.0
# 2037                Belgian Dark Ale          25    16.0
# 2066              English Barleywine          25    16.0
# 2049          Russian Imperial Stout          25    16.0
# 479   American Double / Imperial IPA          24    12.0
# ...                              ...         ...     ...
# 1625         American Pale Wheat Ale         205    12.0
# 945            English Dark Mild Ale         165    16.0
# 851              American Pale Lager         348    12.0
# 2044                     Belgian IPA          25    16.0
# 2051                 American Porter          25    16.0
#
#                        brewery_name           city state
# 2189        Tin Man Brewing Company     Evansville    IN
# 2037       Sun King Brewing Company   Indianapolis    IN
# 2066       Sun King Brewing Company   Indianapolis    IN
# 2049       Sun King Brewing Company   Indianapolis    IN
# 479                Burn 'Em Brewing  Michigan City    IN
# ...                             ...            ...   ...
# 1625       People's Brewing Company      Lafayette    IN
# 945          Great Crescent Brewery         Aurora    IN
# 851   Four Horsemen Brewing Company     South Bend    IN
# 2044       Sun King Brewing Company   Indianapolis    IN
# 2051       Sun King Brewing Company   Indianapolis    IN
#
# [139 rows x 11 columns]

# %% [markdown]
# ## Ejercicio 22
# Obtén una tabla con los principales estadísticos del campo `ibu`,  a nivel ciudad

# %%
new_df.groupby("city")["city"].describe()
# Out:
#                count unique             top freq
# city
# Abingdon           1      1        Abingdon    1
# Abita Springs      3      1   Abita Springs    3
# Ada                1      1             Ada    1
# Afton              4      1           Afton    4
# Airway Heights     5      1  Airway Heights    5
# ...              ...    ...             ...  ...
# Woodinville        4      1     Woodinville    4
# Worcester          1      1       Worcester    1
# Yakima             2      1          Yakima    2
# Yardley            1      1         Yardley    1
# York               4      1            York    4
#
# [384 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 23
# Consigue en un DataFrame todas las cervezas en cuyas cervecerías el mínimo nivel de `abv` sea de 0.07.

# %%
filtrado1=dataset["abv"]==0.07
dataset[filtrado1]
# Out:
#       Unnamed: 0   abv   ibu    id                          name  \
# 28            28  0.07  70.0   799     21st Amendment IPA (2006)
# 29            29  0.07  70.0   797  Brew Free! or Die IPA (2008)
# 30            30  0.07  70.0   796  Brew Free! or Die IPA (2009)
# 37            37  0.07  65.0    10         Brew Free! or Die IPA
# 39            39  0.07  82.0  2519                  Bimini Twist
# ...          ...   ...   ...   ...                           ...
# 2198        2198  0.07  35.0  1754   Parade Ground Coffee Porter
# 2243        2243  0.07  68.0   861                 Cane and Ebel
# 2332        2332  0.07   NaN  2222                        10 Ton
# 2333        2333  0.07   NaN  2221                    Flyin' Rye
# 2335        2335  0.07   NaN  2356   Pay It Forward Cocoa Porter
#
#                     style  brewery_id  ounces
# 28           American IPA         368    12.0
# 29           American IPA         368    12.0
# 30           American IPA         368    12.0
# 37           American IPA         368    12.0
# 39           American IPA          67    12.0
# ...                   ...         ...     ...
# 2198      American Porter         152    12.0
# 2243  American Strong Ale          74    12.0
# 2332        Oatmeal Stout          94    16.0
# 2333         American IPA          94    16.0
# 2335      American Porter         100    12.0
#
# [92 rows x 8 columns]

# %% [markdown]
# ## Ejercicio 24
# Teniendo en cuenta la media de amargor de todas las cervezas, obtén una tabla con las cervezas cuyos estados tengan una media de amargor en cerveza por encima de la media

# %%
filtrado2=dataset["abv"]>dataset["abv"].mean()
dataset[filtrado2]
# Out:
#       Unnamed: 0    abv   ibu    id                         name  \
# 1              1  0.066   NaN  2265                  Devil's Cup
# 2              2  0.071   NaN  2264          Rise of the Phoenix
# 3              3  0.090   NaN  2263                     Sinister
# 4              4  0.075   NaN  2262                Sex and Candy
# 5              5  0.077   NaN  2261                 Black Exodus
# ...          ...    ...   ...   ...                          ...
# 2399        2399  0.069  69.0  1512            Worthy IPA (2013)
# 2400        2400  0.060  50.0  1511                  Worthy Pale
# 2402        2402  0.082   NaN  1316    Colorojo Imperial Red Ale
# 2404        2404  0.075   NaN  1035  Rocky Mountain Oyster Stout
# 2405        2405  0.067  45.0   928                    Belgorado
#
#                                style  brewery_id  ounces
# 1            American Pale Ale (APA)         177    12.0
# 2                       American IPA         177    12.0
# 3     American Double / Imperial IPA         177    12.0
# 4                       American IPA         177    12.0
# 5                      Oatmeal Stout         177    12.0
# ...                              ...         ...     ...
# 2399                    American IPA         199    12.0
# 2400         American Pale Ale (APA)         199    12.0
# 2402             American Strong Ale         424    12.0
# 2404                  American Stout         424    12.0
# 2405                     Belgian IPA         424    12.0
#
# [1017 rows x 8 columns]
