# %% [markdown]
# ![imagen](https://cdn.foodbeast.com/content/wp-content/uploads/2012/03/beer-print-01-selectism.jpg)
#
# # Ejercicio pandas estadistica
# Para este ejercicio se ha utilizado [un dataset de un concurso de kaggle](https://www.kaggle.com/nickhould/craft-cans), cuyo reto consiste en predecir el tipo de cerveza en función de sus características (nivel de alcohol, amargura, tamaño...).
#
# # Ejercicio 1
# Importa las librerias que consideres

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Ejercicio 2
# 1. Importa el dataset "datasets_beer.csv"
# 2. Imprime por pantalla los primeros registros.
# 3. ¿Cuáles son sus columnas?
# 4. ¿Qué dimensiones tiene el DataFrame?

# %%
dataset=pd.read_csv("data\datasets_beers.csv")
dataset.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'abv', 'ibu', 'id', 'name', 'style', 'brewery_id',
#        'ounces'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (2410, 8)

# %% [markdown]
# ## Ejercicio 3
# [Elimina la columna "Unnamed: 0"](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %%
dataset1=dataset.copy()

# %%
dataset1.drop(columns=["Unnamed: 0"])
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
#       brewery_id  ounces
# ...

# %% [markdown]
# ## Ejercicio 4
# ¿Cuántas filas y columnas tiene el dataset?

# %%
print("Filas:", len(dataset))
print("Columnas:", len(dataset.columns))
# Out:
# Filas: 2410
# Columnas: 8

# %% [markdown]
# ## Ejercicio 5
# ¿De qué tipo son los datos?

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2410 non-null   int64
#  1   abv         2348 non-null   float64
#  2   ibu         1405 non-null   float64
#  3   id          2410 non-null   int64
#  4   name        2410 non-null   object
#  5   style       2405 non-null   object
#  6   brewery_id  2410 non-null   int64
#  7   ounces      2410 non-null   float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 150.8+ KB

# %% [markdown]
# ## Ejercicio 6
# Obtén en una nuevo DataFrame un resumen con las principales estadísticas de las columnas numércias: mean, max, count, cuartiles...

# %%
dataset.loc[:,["abv","ibu","ounces"]].describe()
# Out:
#                abv          ibu       ounces
# count  2348.000000  1405.000000  2410.000000
# mean      0.059773    42.713167    13.592241
# std       0.013542    25.954066     2.352204
# min       0.001000     4.000000     8.400000
# 25%       0.050000    21.000000    12.000000
# 50%       0.056000    35.000000    12.000000
# 75%       0.067000    64.000000    16.000000
# max       0.128000   138.000000    32.000000

# %% [markdown]
# ## Ejercicio 7
# ¿Cuántas birras hay de cada estilo en este dataset? [Investiga en la documentación de Series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html) si puedes hacer un conteo de valores.

# %%
dataset["style"].value_counts()
# Out:
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
#                                  ...
# American Malt Liquor                1
# Wheat Ale                           1
# Flanders Red Ale                    1
# Kristalweizen                       1
# Low Alcohol Beer                    1
# Name: style, Length: 99, dtype: int64

# %% [markdown]
# ## Ejercicio 8
# 1. Imprime por pantalla los registros del 10 al 20
# 2. De esos registros, imprime por pantalla desde la columna `name` a `ounces`, ambas incluidas
# 3. Quédate con las columnas `abv`, `ibu` y `ounces`, y además quédate sólo con los registros 10 al 20.
# 4. Convierte el resultado del apartado 3 en un array de `numpy`

# %%
dataset2=dataset.iloc[10:21,:].copy()
dataset2
# Out:
#     Unnamed: 0    abv   ibu    id                          name  \
# 10          10  0.072   NaN  2099             Sophomoric Saison
# 11          11  0.073   NaN  2098         Regional Ring Of Fire
# 12          12  0.069   NaN  2097                    Garce Selé
# 13          13  0.085   NaN  1980               Troll Destroyer
# 14          14  0.061  60.0  1979                  Bitter Bitch
# 15          15  0.060   NaN  2318                   Ginja Ninja
# 16          16  0.060   NaN  2170                 Cherried Away
# 17          17  0.060   NaN  2169                  Rhubarbarian
# 18          18  0.060   NaN  1502                   BrightCider
# 19          19  0.082   NaN  1593   He Said Baltic-Style Porter
# 20          20  0.082   NaN  1592  He Said Belgian-Style Tripel
#
#                       style  brewery_id  ounces
# 10   Saison / Farmhouse Ale         177    12.0
# 11   Saison / Farmhouse Ale         177    12.0
# 12   Saison / Farmhouse Ale         177    12.0
# ...

# %%
dataset2.loc[:,"name":]
# Out:
#                             name                    style  brewery_id  ounces
# 10             Sophomoric Saison   Saison / Farmhouse Ale         177    12.0
# 11         Regional Ring Of Fire   Saison / Farmhouse Ale         177    12.0
# 12                    Garce Selé   Saison / Farmhouse Ale         177    12.0
# 13               Troll Destroyer              Belgian IPA         177    12.0
# 14                  Bitter Bitch  American Pale Ale (APA)         177    12.0
# 15                   Ginja Ninja                    Cider         154    12.0
# 16                 Cherried Away                    Cider         154    12.0
# 17                  Rhubarbarian                    Cider         154    12.0
# 18                   BrightCider                    Cider         154    12.0
# 19   He Said Baltic-Style Porter            Baltic Porter         368    12.0
# 20  He Said Belgian-Style Tripel                   Tripel         368    12.0

# %%
dataset2[["abv","ibu","ounces"]]
# Out:
#       abv   ibu  ounces
# 10  0.072   NaN    12.0
# 11  0.073   NaN    12.0
# 12  0.069   NaN    12.0
# 13  0.085   NaN    12.0
# 14  0.061  60.0    12.0
# 15  0.060   NaN    12.0
# 16  0.060   NaN    12.0
# 17  0.060   NaN    12.0
# 18  0.060   NaN    12.0
# 19  0.082   NaN    12.0
# 20  0.082   NaN    12.0

# %%
np.array(dataset2)
# Out:
# array([[10, 0.072, nan, 2099, 'Sophomoric Saison',
#         'Saison / Farmhouse Ale', 177, 12.0],
#        [11, 0.073, nan, 2098, 'Regional Ring Of Fire',
#         'Saison / Farmhouse Ale', 177, 12.0],
#        [12, 0.069, nan, 2097, 'Garce Selé', 'Saison / Farmhouse Ale',
#         177, 12.0],
#        [13, 0.085, nan, 1980, 'Troll Destroyer', 'Belgian IPA', 177,
#         12.0],
#        [14, 0.061, 60.0, 1979, 'Bitter Bitch', 'American Pale Ale (APA)',
#         177, 12.0],
#        [15, 0.06, nan, 2318, 'Ginja Ninja', 'Cider', 154, 12.0],
#        [16, 0.06, nan, 2170, 'Cherried Away', 'Cider', 154, 12.0],
#        [17, 0.06, nan, 2169, 'Rhubarbarian', 'Cider', 154, 12.0],
#        [18, 0.06, nan, 1502, 'BrightCider', 'Cider', 154, 12.0],
#        [19, 0.0819999999999999, nan, 1593, 'He Said Baltic-Style Porter',
#         'Baltic Porter', 368, 12.0],
#        [20, 0.0819999999999999, nan, 1592,
#         'He Said Belgian-Style Tripel', 'Tripel', 368, 12.0]],
# ...

# %% [markdown]
# ## Ejercicio 9
# ¿Cuántas onzas pesan todas las birras del dataset?

# %%
dataset["ounces"].sum()
# Out:
# 32757.3

# %% [markdown]
# ## Ejercicio 10
# El amargor de las cervezas se mide por su nivel de IBUs.
# 1. ¿Cuál es el amargor medio de las cervezas?
# 2. ¿El máximo? ¿Y el mínimo?
# 3. ¿Qué cerveza es la que tiene el amargor máximo? ¿Cuál es la de amargor mínimo?

# %% [markdown]
# dataset.head()

# %%
print("Amargor medio de las cervezas:", dataset["ibu"].mean())
print("Amargor máximo de las cervezas:", dataset["ibu"].max())
print("Amargor mínimo de las cervezas:", dataset["ibu"].min())
# Out:
# Amargor medio de las cervezas: 42.71316725978647
# Amargor máximo de las cervezas: 138.0
# Amargor mínimo de las cervezas: 4.0

# %%
filtrado=dataset["ibu"]==dataset["ibu"].max()
dataset[filtrado]
# Out:
#      Unnamed: 0    abv    ibu   id                       name  \
# 147         147  0.082  138.0  980  Bitter Bitch Imperial IPA
#
#                               style  brewery_id  ounces
# 147  American Double / Imperial IPA         374    12.0

# %%
filtrado=dataset["ibu"]==dataset["ibu"].min()
dataset[filtrado]
# Out:
#      Unnamed: 0    abv  ibu    id                                  name  \
# 106         106  0.056  4.0  1350                       Summer Solstice
# 112         112  0.056  4.0   753  Summer Solstice Cerveza Crema (2009)
# 117         117  0.056  4.0    77                Summer Solstice (2011)
#
#          style  brewery_id  ounces
# 106  Cream Ale         171    12.0
# 112  Cream Ale         171    12.0
# 117  Cream Ale         171    12.0

# %% [markdown]
# ## Ejercicio 11
# No queda muy claro cuánto de dispar, de dispersa, es la medida de IBU. Mediante estadística descriptiva (una o dos métricas, sin gráficas), razona la dispersión de la variable IBU.

# %%
std_beers=dataset["ibu"].std()
mean_beers=dataset["ibu"].mean()

print(f"La media es {mean_beers:.2f} y la desviacion estandar es {std_beers:.2f}")
# Out:
# La media es 42.71 y la desviacion estandar es 25.95

# %%
q1=dataset["ibu"].quantile(.25)
q3=dataset["ibu"].quantile(.75)

iqr=q3-q1 #Rango intercuartílico
print(f"El amargor de la cerveza se encuentra entre {q1} y {q3}")
# Out:
# El amargor de la cerveza se encuentra entre 21.0 y 64.0

# %% [markdown]
# ## Ejercicio 12
# ¿Existe alguna relación lineal entre las variables numéricas del dataset? Intenta pintar este razonmiento mediante un gráfico

# %%
import matplotlib.pyplot as plt

dataset.drop(columns=["id","brewery_id","Unnamed: 0"]).corr()
# Out:
#              abv       ibu    ounces
# abv     1.000000  0.670621  0.172529
# ibu     0.670621  1.000000  0.054691
# ounces  0.172529  0.054691  1.000000

# %%
import seaborn  as sns
sns.regplot(x="abv", y="ibu", data=dataset)
# Out:
# <AxesSubplot:xlabel='abv', ylabel='ibu'>

# %% [markdown]
# ## Ejercicio 13
# Representa el nivel de alcohol (columna `abv`) en un histograma. ¿Se trata de una distribución simétrica o asimétrica?

# %%
import matplotlib.pyplot as plt
sample_data = dataset["abv"]
plt.hist(sample_data)
# Out:
# (array([  1.,   0.,  38., 699., 857., 486., 159., 104.,   1.,   3.]),
#  array([0.001 , 0.0137, 0.0264, 0.0391, 0.0518, 0.0645, 0.0772, 0.0899,
#         0.1026, 0.1153, 0.128 ]),
#  <BarContainer object of 10 artists>)

# %%
dataset["abv"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Ejercicio 14
# Representa mediante un *boxplot* de `seaborn` la variable `abv`

# %%
import seaborn as sns

sns.boxplot(data=dataset["abv"])

#El centro de la caja es la mediana y la linea de la caja es la media
#Los bigotes miden 1.5 la caja
#Los demás puntos son números anormales, o se han medido mal o hay excepciones
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Ejercicio 15
# 1. ¿Qué estilos son los que tienen en media más alcohol?
# 2. ¿Y los estilos que son en media más amargos?

# %%
dataset.groupby("style")["abv"].mean().sort_values(ascending=False)
# Out:
# style
# English Barleywine        0.107667
# Quadrupel (Quad)          0.104000
# American Barleywine       0.099000
# American Malt Liquor      0.099000
# Russian Imperial Stout    0.097636
#                             ...
# Berliner Weissbier        0.043909
# English Dark Mild Ale     0.041500
# Light Lager               0.040417
# Radler                    0.040333
# Low Alcohol Beer          0.001000
# Name: abv, Length: 99, dtype: float64

# %%
dataset.groupby("ibu")["ounces"].mean().sort_values(ascending=False)
# Out:
# ibu
# 66.0     16.8
# 101.0    16.0
# 91.0     16.0
# 120.0    16.0
# 57.0     16.0
#          ...
# 49.0     12.0
# 41.0     12.0
# 39.0     12.0
# 14.0     12.0
# 138.0    12.0
# Name: ounces, Length: 107, dtype: float64

# %% [markdown]
# ## Ejercicio 16
# Carga el datasets de cervecerias `datasets_breweries.csv`

# %%
breweries=pd.read_csv("data\datasets_breweries.csv")

# %% [markdown]
# ## Ejercicio 17
# 1. Renombra la columna `Unnamed: 0` como `brewery_id`
# 2. Renombra tb la columna `name` por `brewery_name`. ¿Puedes hacer ambos apartados en una sola sentencia?

# %%
breweries1=breweries.rename(columns = {'Unnamed: 0':'brewery_id', "name":"brewery_name"})
breweries1
# Out:
#      brewery_id                   brewery_name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 18
# Junta los dos datasets que tienes

# %%
new_df=pd.merge(dataset,breweries1, on="brewery_id", how="left")
new_df
# Out:
#       Unnamed: 0    abv   ibu    id                  name  \
# 0              0  0.050   NaN  1436              Pub Beer
# 1              1  0.066   NaN  2265           Devil's Cup
# 2              2  0.071   NaN  2264   Rise of the Phoenix
# 3              3  0.090   NaN  2263              Sinister
# 4              4  0.075   NaN  2262         Sex and Candy
# ...          ...    ...   ...   ...                   ...
# 2405        2405  0.067  45.0   928             Belgorado
# 2406        2406  0.052   NaN   807         Rail Yard Ale
# 2407        2407  0.055   NaN   620       B3K Black Lager
# 2408        2408  0.055  40.0   145   Silverback Pale Ale
# 2409        2409  0.052   NaN    84  Rail Yard Ale (2009)
#
#                                style  brewery_id  ounces  \
# 0                American Pale Lager         408    12.0
# 1            American Pale Ale (APA)         177    12.0
# 2                       American IPA         177    12.0
# ...

# %% [markdown]
# ## Ejercicio 19
# 1. ¿Cuántos estados diferentes hay?
# 2. ¿Y ciudades diferentes?
# 3. ¿Cuántas cervecerías hay?

# %%
print("Total de estados:", len(new_df.groupby("state").count()))
print("Total de ciudades:", len(new_df.groupby("city").count()))
print("Total de estados:", len(new_df.groupby("brewery_name").count()))
# Out:
# Total de estados: 51
# Total de ciudades: 384
# Total de estados: 551

# %%
new_df.groupby("state").nunique()
# Out:
#        Unnamed: 0  abv  ibu   id  name  style  brewery_id  ounces  \
# state
#  AK            25   16   13   25    25     14           7       1
#  AL            10    7    8   10    10      8           3       1
#  AR             5    5    1    5     5      5           2       1
#  AZ            47   21   12   47    46     18          11       2
#  CA           183   51   55  183   173     46          39       5
#  CO           265   50   53  265   252     60          47       4
#  CT            27   16    5   27    27     15           8       2
#  DC             8    8    4    8     8      8           1       1
#  DE             2    1    1    2     2      2           2       2
#  FL            58   23   22   58    57     19          15       2
#  GA            16   12    5   16    16      9           7       1
#  HI            27   18   13   27    22     15           4       4
#  IA            30   16   18   30    30     17           5       2
# ...

# %% [markdown]
# ## Ejercicio 20
# Agrupa por estado y ciudad, la media, mediana y máximo nivel de alcohol

# %%
new_df.groupby(["state","city"])["abv"].aggregate(["mean","median","max"])
# Out:
#                       mean  median    max
# state city
#  AK   Anchorage   0.054200  0.0520  0.063
#       Juneau      0.053000  0.0530  0.053
#       Soldotna    0.058500  0.0580  0.068
#       Talkeetna   0.059500  0.0585  0.065
#  AL   Birmingham  0.065400  0.0600  0.093
# ...                    ...     ...    ...
#  WI   Wilson      0.055000  0.0550  0.055
#  WV   Lewisburg   0.062000  0.0620  0.067
#  WY   Jackson     0.054857  0.0520  0.068
#       Pinedale    0.061000  0.0610  0.072
#       Sheridan    0.052833  0.0480  0.070
#
# [401 rows x 3 columns]

# %%
pd.pivot_table(new_df, index=["state","city"], values="abv", aggfunc=["mean","median","max"])
# Out:
#                       mean  median    max
#                        abv     abv    abv
# state city
#  AK   Anchorage   0.054200  0.0520  0.063
#       Juneau      0.053000  0.0530  0.053
#       Soldotna    0.058500  0.0580  0.068
#       Talkeetna   0.059500  0.0585  0.065
#  AL   Birmingham  0.065400  0.0600  0.093
# ...                    ...     ...    ...
#  WI   Wilson      0.055000  0.0550  0.055
#  WV   Lewisburg   0.062000  0.0620  0.067
#  WY   Jackson     0.054857  0.0520  0.068
#       Pinedale    0.061000  0.0610  0.072
#       Sheridan    0.052833  0.0480  0.070
#
# [393 rows x 3 columns]

# %% [markdown]
# ## Ejercicio 21
# ¿Cuáles son las cervezas más amargas que se consumen en Indiana, estado = `IN`?

# %%
filtrado3=(new_df["state"]==" IN")
#El método str.strip elimina todos los espacios delante y detrás

new_df[filtrado3].sort_values("ibu",ascending=False)
# Out:
#       Unnamed: 0    abv    ibu    id                          name  \
# 479          479  0.099  115.0  2471              Hopkick Dropkick
# 2191        2191  0.085  115.0  1449         Overlord Imperial IPA
# 811          811  0.060  104.0  1610                Half Cycle IPA
# 2062        2062  0.091   91.0   651                          Isis
# 2189        2189  0.120   90.0  2621                          Csar
# ...          ...    ...    ...   ...                           ...
# 2056        2056  0.070    NaN   934                     The Deuce
# 2061        2061  0.080    NaN   660                         Chaka
# 2190        2190  0.055    NaN  1817  Klingon Warnog Roggen Dunkel
# 2277        2277  0.060    NaN  1950                 Dragonfly IPA
# 2329        2329  0.047    NaN   780            T-6 Red Ale (2004)
#
#                                style  brewery_id  ounces  \
# 479   American Double / Imperial IPA          24    12.0
# ...

# %% [markdown]
# ## Ejercicio 22
# Obtén una tabla con los principales estadísticos del campo `ibu`,  a nivel ciudad

# %%
new_df.groupby("city")["ibu"].describe()
# Out:
#                 count        mean        std    min     25%    50%     75%  \
# city
# Abingdon          1.0  135.000000        NaN  135.0  135.00  135.0  135.00
# Abita Springs     3.0   27.333333  21.455380   13.0   15.00   17.0   34.50
# Ada               0.0         NaN        NaN    NaN     NaN    NaN     NaN
# Afton             4.0   43.000000  19.899749   22.0   28.00   45.0   60.00
# Airway Heights    0.0         NaN        NaN    NaN     NaN    NaN     NaN
# ...               ...         ...        ...    ...     ...    ...     ...
# Woodinville       4.0   46.750000  18.643587   27.0   39.75   44.0   51.00
# Worcester         1.0   69.000000        NaN   69.0   69.00   69.0   69.00
# Yakima            2.0   54.000000  22.627417   38.0   46.00   54.0   62.00
# Yardley           0.0         NaN        NaN    NaN     NaN    NaN     NaN
# York              4.0   44.250000  22.779742   20.0   35.00   41.0   50.25
#
#                   max
# city
# Abingdon        135.0
# ...

# %% [markdown]
# ## Ejercicio 23
# Consigue en un DataFrame todas las cervezas en cuyas cervecerías el mínimo nivel de `abv` sea de 0.07.

# %%
abv_thresh=.07
new_df.groupby("brewery_id")[["brewery_id","brewery_name","abv"]].filter(lambda x: (x["abv"]>abv_thresh).all())
# Out:
#       brewery_id                        brewery_name    abv
# 212          306               Beach Brewing Company  0.088
# 275           18              Black Acre Brewing Co.  0.072
# 286           95                  Blackrocks Brewery  0.073
# 309          304                  Blue Hills Brewery  0.080
# 354          231         Borderlands Brewing Company  0.071
# 594           99  Christian Moerlein Brewing Company  0.089
# 690          358           Daredevil Brewing Company  0.072
# 1142         208              Kalona Brewing Company  0.071
# 1143         208              Kalona Brewing Company  0.075
# 1186         354                     Kulshan Brewery  0.080
# 1409         260      Mountain Town Brewing Company   0.082
# 1666         274                    Portside Brewery  0.099
# 1702         421                    Redstone Meadery  0.080
# 1703         421                    Redstone Meadery  0.080
# 1704         421                    Redstone Meadery  0.080
# ...

# %%
eliminar=new_df[new_df["abv"]<=.07]["brewery_name"].unique()
# new_df[lambda x: x["brewery_name"] == eliminar]
filtrado=new_df["brewery_name"].isin(eliminar)

# %% [markdown]
# ## Ejercicio 24
# Teniendo en cuenta la media de amargor de todas las cervezas, obtén una tabla con las cervezas cuyos estados tengan una media de amargor en cerveza por encima de la media

# %%
filtrado2=dataset["ibu"]>dataset["ibu"].mean()
dataset[filtrado2]
# Out:
#       Unnamed: 0    abv   ibu    id                          name  \
# 14            14  0.061  60.0  1979                  Bitter Bitch
# 21            21  0.099  92.0  1036                 Lower De Boom
# 22            22  0.079  45.0  1024                 Fireside Chat
# 28            28  0.070  70.0   799     21st Amendment IPA (2006)
# 29            29  0.070  70.0   797  Brew Free! or Die IPA (2008)
# ...          ...    ...   ...   ...                           ...
# 2395        2395  0.065  69.0  1697                  Be Hoppy IPA
# 2396        2396  0.069  69.0  2194                    Worthy IPA
# 2399        2399  0.069  69.0  1512             Worthy IPA (2013)
# 2400        2400  0.060  50.0  1511                   Worthy Pale
# 2405        2405  0.067  45.0   928                     Belgorado
#
#                         style  brewery_id  ounces
# 14    American Pale Ale (APA)         177    12.0
# 21        American Barleywine         368     8.4
# ...
